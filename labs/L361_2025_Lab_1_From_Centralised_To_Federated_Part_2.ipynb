# %% [markdown]
# # 0. Marking and Guidelines
# ---
# ***IMPORTANT***
#
# > The **attendance** and **active participation** in the **lab sessions** is **strongly recommended** and will be considered for grading.
# >
# > Save a copy of this notebook into your Drive before you start
# >
# > Please attempt all the **questions** marked for your **group** (Part II ✅ | Part III/MPhil ✅).
# >
# > Please, provide your answers in a **new cell below the question cell**. You can make as many new cells as you need.
#
# Please submit a `.zip` file, containing both parts, consisting of:
# 1. A text file with a **publicly** visible link to your notebooks in GitHub.
# 2. A **downloaded copy** (`.ipynb`) of your notebooks or your zipped cloned GitHub repo. You may treat these as a report---we will not be re-executing the code you used to produce the answers unless required.
#
#
# Feel free to attempt more in case you find yourself enjoying the material!
# If you have any questions, please ask them to the teaching assistants.
# Are you interested in knowing more about federated learning and related topics? Reach out to the teaching assistants for additional resources and ask more about the current research projects.

# %% [markdown]
# ## Dependencies
# ---

# %%
# `pip` could produce some errors. Do not worry about them.
# The execution has been verified; it's working anyway.
! pip install --quiet --upgrade "pip"
! pip install --quiet matplotlib tqdm seaborn
! pip install git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching \
    torch torchvision ray=="2.6.3"
# Out:
# Collecting git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching
#   Cloning https://github.com/Iacob-Alexandru-Andrei/flower.git (to revision teaching) to /private/var/folders/sp/f__fqm8170x9blb4phh74rvr0000gn/T/pip-req-build-k6bhwjq7
#   Running command git clone --filter=blob:none --quiet https://github.com/Iacob-Alexandru-Andrei/flower.git /private/var/folders/sp/f__fqm8170x9blb4phh74rvr0000gn/T/pip-req-build-k6bhwjq7
#   Running command git checkout -b teaching --track origin/teaching
#   Switched to a new branch 'teaching'
#   branch 'teaching' set up to track 'origin/teaching'.
#   Resolved https://github.com/Iacob-Alexandru-Andrei/flower.git to commit 1c4fcc1d4a6e8022ddf6f94ebedef1b8e70e0fc4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: torchvision in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (0.21.0)
# Requirement already satisfied: ray==2.6.3 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (2.6.3)
# Requirement already satisfied: click>=7.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (8.1.7)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (3.13.3)
# Requirement already satisfied: jsonschema in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (1.0.8)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (24.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (3.20.3)
# Requirement already satisfied: pyyaml in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (6.0.1)
# Requirement already satisfied: aiosignal in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (1.4.1)
# Requirement already satisfied: requests in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (2.31.0)
# Requirement already satisfied: grpcio>=1.42.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (1.70.0)
# Requirement already satisfied: numpy>=1.19.3 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from ray==2.6.3) (1.26.4)
# Requirement already satisfied: cryptography<42.0.0,>=41.0.2 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from flwr==1.7.0) (41.0.7)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from flwr==1.7.0) (0.0.2)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from flwr==1.7.0) (3.21.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from torch) (4.10.0)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from cryptography<42.0.0,>=41.0.2->flwr==1.7.0) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from jsonschema->ray==2.6.3) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from jsonschema->ray==2.6.3) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from jsonschema->ray==2.6.3) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from jsonschema->ray==2.6.3) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from requests->ray==2.6.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from requests->ray==2.6.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from requests->ray==2.6.3) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from requests->ray==2.6.3) (2024.2.2)
# Requirement already satisfied: pycparser in /opt/homebrew/anaconda3/envs/marl-formation/lib/python3.11/site-packages (from cffi>=1.12->cryptography<42.0.0,>=41.0.2->flwr==1.7.0) (2.22)

# %% [markdown]
# ### Imports.

# %%
import random
from pathlib import Path
import tarfile
from typing import Any
from logging import INFO
from collections import defaultdict, OrderedDict
from collections.abc import Sequence, Callable
import numbers

import numpy as np
import torch
from torch import nn
from torch.nn import Module
from torch.utils.data import DataLoader, Dataset
from enum import IntEnum
import flwr
from flwr.server import History, ServerConfig
from flwr.server.strategy import FedAvgM as FedAvg, Strategy
from flwr.common import log, NDArrays, Scalar, Parameters, ndarrays_to_parameters
from flwr.client.client import Client

from common.client_utils import (
    Net,
    load_femnist_dataset,
    get_network_generator_cnn as get_network_generator,
    train_femnist,
    test_femnist,
    save_history,
)


# Add new seeds here for easy autocomplete
class Seeds(IntEnum):
    """Seeds for reproducibility."""

    DEFAULT = 1337


np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True


PathType = Path | str | None


def get_device() -> str:
    """Get the device (cuda, mps, cpu)."""
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda"
    elif torch.backends.mps.is_available() and torch.backends.mps.is_built():
        device = "mps"
    return device

# %%
home_dir = Path.cwd()
dataset_dir: Path = home_dir / "femnist"
data_dir: Path = dataset_dir / "data"
centralized_partition: Path = dataset_dir / "client_data_mappings" / "centralized"
centralized_mapping: Path = dataset_dir / "client_data_mappings" / "centralized" / "0"
federated_partition: Path = dataset_dir / "client_data_mappings" / "fed_natural"

# Decompress dataset
if not dataset_dir.exists():
    with tarfile.open(home_dir / "femnist.tar.gz", "r:gz") as tar:
        tar.extractall(path=home_dir)
    log(INFO, "Dataset extracted in %s", dataset_dir)

# %% [markdown]
# ## 5. Building a Flower FL client.
# ---

# %% [markdown]
# Our first client abstraction shall be as simple as possible and will require adjustment to match the structure that the flower framework expects. However, it shall be conceptually identical and require only light API changes.

# %% [markdown]
# Moving from centralised ML to server-client FL requires us to provide a means of communication between the respective server and clients. The Flower Framework is ML-framework agnostic and allows various means of transmitting model parameters in the federated network. Since you may have limited resources in these labs, we will only tangentially follow the Flower framework while keeping the computational requirements to a minimum.
#
# The simplest and most common encoding for models is the mere transmission of model parameters as NumPy arrays instead of the stateful PyTorch models. The following functions allow for seamless conversions between the two.

# %%
def set_model_parameters(net: Module, parameters: NDArrays) -> Module:
    """Put a set of parameters into the model object.

    Parameters
    ----------
        net (Module): model object.
        parameters (NDArrays): set of parameters to put into the model.

    Returns
    -------
        Module: updated model object.
    """
    weights = parameters
    params_dict = zip(net.state_dict().keys(), weights, strict=False)
    state_dict = OrderedDict({k: torch.from_numpy(np.copy(v)) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)
    return net


def get_model_parameters(net: Module) -> NDArrays:
    """Get the current model parameters as NDArrays.

    Parameters
    ----------
        net (Module): current model object.

    Returns
    -------
        NDArrays: set of parameters from the current model.
    """
    return [val.cpu().numpy() for _, val in net.state_dict().items()]

# %% [markdown]
# With them in place, making the client abstraction compatible with Flower requires only a bit of boilerplate such as allowing NumPy arrays to be received and sent instead of PyTorch models. To achieve this, we provide a model generator capable of creating a network and using the received parameters.
#
# To keep client objects light in the memory when not used by the Flower FL simulator, the model generator is only called as needed for either `fit` or `evaluate`.

# %%
class FlowerRayClient(flwr.client.NumPyClient):
    """Flower client for the FEMNIST dataset."""

    def __init__(
        self,
        cid: int,
        partition_dir: Path,
        model_generator: Callable[[], Module],
    ) -> None:
        """Init the client with its unique id and the folder to load data from.

        Parameters
        ----------
            cid (int): Unique client id for a client used to map it to its data
                partition
            partition_dir (Path): The directory containing data for each
                client/client id
            model_generator (Callable[[], Module]): The model generator function
        """
        self.cid = cid
        log(INFO, "cid: %s", self.cid)
        self.partition_dir = partition_dir
        self.device = str(
            torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        )
        self.model_generator: Callable[[], Module] = model_generator
        self.properties: dict[str, Scalar] = {"tensor_type": "numpy.ndarray"}

    def set_parameters(self, parameters: NDArrays) -> Module:
        """Load weights inside the network.

        Parameters
        ----------
            parameters (NDArrays): set of weights to be loaded.

        Returns
        -------
            [Module]: Network with new set of weights.
        """
        net = self.model_generator()
        return set_model_parameters(net, parameters)

    def get_parameters(self, config: dict[str, Scalar]) -> NDArrays:
        """Return weights from a given model.

        If no model is passed, then a local model is created.
        This can be used to initialise a model in the
        server.
        The config param is not used but is mandatory in Flower.

        Parameters
        ----------
            config (dict[int, Scalar]): dictionary containing configuration info.

        Returns
        -------
            NDArrays: weights from the model.
        """
        net = self.model_generator()
        return get_model_parameters(net)

    def fit(
        self, parameters: NDArrays, config: dict[str, Scalar]
    ) -> tuple[NDArrays, int, dict]:
        """Receive and train a model on the local client data.

        It uses parameters from the config dict

        Parameters
        ----------
            net (NDArrays): Pytorch model parameters
            config (dict[str, Scalar]): dictionary describing the training parameters

        Returns
        -------
            tuple[NDArrays, int, dict]: Returns the updated model, the size of the local
                dataset and other metrics
        """
        # Only create model right before training/testing
        # To lower memory usage when idle
        net = self.set_parameters(parameters)
        net.to(self.device)

        train_loader: DataLoader = self._create_data_loader(config, name="train")
        train_loss = self._train(net, train_loader=train_loader, config=config)
        return get_model_parameters(net), len(train_loader), {"train_loss": train_loss}

    def evaluate(
        self, parameters: NDArrays, config: dict[str, Scalar]
    ) -> tuple[float, int, dict]:
        """Receive and test a model on the local client data.

        It uses parameters from the config dict

        Parameters
        ----------
            net (NDArrays): Pytorch model parameters
            config (dict[str, Scalar]): dictionary describing the testing parameters

        Returns
        -------
            tuple[float, int, dict]: Returns the loss accumulate during testing, the
                size of the local dataset and other metrics such as accuracy
        """
        net = self.set_parameters(parameters)
        net.to(self.device)

        test_loader: DataLoader = self._create_data_loader(config, name="test")
        loss, accuracy = self._test(net, test_loader=test_loader, config=config)
        return loss, len(test_loader), {"local_accuracy": accuracy}

    def _create_data_loader(self, config: dict[str, Scalar], name: str) -> DataLoader:
        """Create the data loader using the specified config parameters.

        Parameters
        ----------
            config (dict[str, Scalar]): dictionary containing dataloader and dataset
                parameters
            mode (str): Load the training or testing set for the client

        Returns
        -------
            DataLoader: A pytorch dataloader iterable for training/testing
        """
        batch_size = int(config["batch_size"])
        num_workers = int(config["num_workers"])
        dataset = self._load_dataset(name)
        return DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=True,
            num_workers=num_workers,
            drop_last=(name == "train"),
        )

    def _load_dataset(self, name: str) -> Dataset:
        full_file: Path = self.partition_dir / str(self.cid)
        return load_femnist_dataset(
            mapping=full_file,
            name=name,
            data_dir=data_dir,
        )

    def _train(
        self, net: Module, train_loader: DataLoader, config: dict[str, Scalar]
    ) -> float:
        return train_femnist(
            net=net,
            train_loader=train_loader,
            epochs=int(config["epochs"]),
            device=self.device,
            optimizer=torch.optim.AdamW(
                net.parameters(),
                lr=float(config["client_learning_rate"]),
                weight_decay=float(config["weight_decay"]),
            ),
            criterion=torch.nn.CrossEntropyLoss(),
            max_batches=int(config["max_batches"]),
        )

    def _test(
        self, net: Module, test_loader: DataLoader, config: dict[str, Scalar]
    ) -> tuple[float, float]:
        return test_femnist(
            net=net,
            test_loader=test_loader,
            device=self.device,
            criterion=torch.nn.CrossEntropyLoss(),
            max_batches=int(config["max_batches"]),
        )

    def get_properties(self, config: dict[str, Scalar]) -> dict[str, Scalar]:
        """Return properties for this client.

        Parameters
        ----------
            config (dict[str, Scalar]): Options to be used for selecting specific
            properties.

        Returns
        -------
            dict[str, Scalar]: Returned properties.
        """
        return self.properties

    def get_train_set_size(self) -> int:
        """Return the client train set size.

        Returns
        -------
            int: train set size of the client.
        """
        return len(self._load_dataset("train"))  # type: ignore[reportArgumentType]

    def get_test_set_size(self) -> int:
        """Return the client test set size.

        Returns
        -------
            int: test set size of the client.
        """
        return len(self._load_dataset("test"))  # type: ignore[reportArgumentType]


def fit_client_seeded(
    client: FlowerRayClient,
    params: NDArrays,
    conf: dict[str, Any],
    seed: Seeds = Seeds.DEFAULT,
    **kwargs: Any,
) -> tuple[NDArrays, int, dict]:
    """Wrap to always seed client training."""
    np.random.seed(seed)
    torch.manual_seed(seed)
    random.seed(seed)
    return client.fit(params, conf, **kwargs)

# %% [markdown]
# The underlying FL simulator used by Flower is based on [Ray](https://www.ray.io/). It expects each client only to require a client ID for instantiation. Therefore, using the following generator function, we can determine the specific network used for FL together with the FEMNIST partition to which the `cid` refers.
#
# While we will not use `Ray` in this lab due to its heavyweight nature, we will keep all code API compatible with the default flower framework.

# %%
def get_flower_client_generator(
    model_generator: Callable[[], Module],
    partition_dir: Path,
    mapping_fn: Callable[[int], int] | None = None,
) -> Callable[[str], FlowerRayClient]:
    """Wrap the client instance generator.

    This provides the client generator with a model generator function.
    Also, the partition directory must be passed.
    A mapping function could be used for filtering/ordering clients.

    Parameters
    ----------
        model_generator (Callable[[], Module]): model generator function.
        partition_dir (Path): directory containing the partition.
        mapping_fn (Optional[Callable[[int], int]]): function mapping sorted/filtered
            ids to real cid.

    Returns
    -------
        Callable[[str], FlowerRayClient]: client instance.
    """

    def client_fn(cid: str) -> FlowerRayClient:
        """Create a single client instance given the client id `cid`.

        Parameters
        ----------
            cid (str): client id, Flower requires this to be of type str.

        Returns
        -------
            FlowerRayClient: client instance.
        """
        return FlowerRayClient(
            cid=mapping_fn(int(cid)) if mapping_fn is not None else int(cid),
            partition_dir=partition_dir,
            model_generator=model_generator,
        )

    return client_fn

# %% [markdown]
# To ensure the Flower client behaves the same as our simple demo client, a simple test using the centralised partition we defined earlier should suffice.

# %%
network_generator = get_network_generator()
seed_net: Net = network_generator()
seed_model_params: NDArrays = get_model_parameters(seed_net)

centralized_flower_client_generator: Callable[[str], FlowerRayClient] = (
    get_flower_client_generator(network_generator, centralized_partition)
)
centralized_flower_client = centralized_flower_client_generator(str(0))
# Out:
# INFO flwr 2025-02-07 12:52:20,267 | 2290543087.py:21 | cid: 0

# %%
centralized_train_config: dict[str, Any] = {
    "epochs": 1,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

test_config: dict[str, Any] = {
    "batch_size": 32,
    "num_workers": 0,
    "max_batches": 100,
}

# Train parameters on the centralised dataset
trained_params, num_examples, train_metrics = fit_client_seeded(
    centralized_flower_client, params=seed_model_params, conf=centralized_train_config
)
log(INFO, "Train Metrics = %s", train_metrics)
# Out:
# INFO flwr 2025-02-07 12:52:25,595 | 4024557794.py:20 | Train Metrics = {'train_loss': 0.11729415073990822}

# %%
# Test trained parameters on the centralised dataset
loss, num_examples, test_metrics = centralized_flower_client.evaluate(
    parameters=trained_params, config=test_config
)
log(INFO, "Loss = %s; Test Metrics = %s", loss, test_metrics)
# Out:
#   4%|▍         | 100/2329 [00:01<00:39, 56.92it/s]
# INFO flwr 2025-02-07 12:52:27,451 | 592755603.py:5 | Loss = 370.12767148017883; Test Metrics = {'local_accuracy': 0.059375}

# %% [markdown]
# ## 6. FL with natural partitions
# ---

# %% [markdown]
# Given its naturally-partitioned nature, we can easily construct a realistic FL experiment by mapping clients one-to-one with the writers of the original symbols.
#
# To pursue this aim, we shall use the “naturally federated” partition instead of the "centralised” one. We are then using the entire `train.csv` and `test.csv` contained in the subfolders of `client_data_mappings/fed_natural`. Each subfolder is named after the clients' ID in the dataset, i.e., from `0` to `3229`.
#
# To guarantee that each client has sufficient training data to participate meaningfully, a common practice is to set a lower bound on the number of samples a selected client is allowed to have. Generally, this threshold should be equivalent to at least one batch. We will now implement a function to sample clients from the federation that satisfies the abovementioned filter in the train set.

# %%
def sample_random_clients(
    total_clients: int,
    filter_less: int,
    partition: Path,
    seed: int | None = Seeds.DEFAULT,
) -> Sequence[int]:
    """Sample randomly clients.

    A filter on the client train set size is performed.

    Parameters
    ----------
        total_clients (int): total number of clients to sample.
        filter_less (int): max number of train samples for which the client is
            **discarded**.
        partition (Path): path to the folder containing the partitioning.
        seed (Optional[int], optional): seed for the random generator. Defaults to None.

    Returns
    -------
        Sequence[int]: list of sample client ids as int.
    """
    real_federated_cid_client_generator: Callable[[str], FlowerRayClient] = (
        get_flower_client_generator(network_generator, federated_partition)
    )
    if seed is not None:
        random.seed(seed)
    list_of_ids = []
    while len(list_of_ids) < total_clients:
        current_id = random.randint(0, 3229)
        if (
            real_federated_cid_client_generator(str(current_id)).get_train_set_size()
            > filter_less
        ):
            list_of_ids.append(current_id)
    return list_of_ids

# %% [markdown]
# While FEMNIST has more than 3000 clients, our small-scale experiments will not require more than 100 at any point.

# %%
total_clients: int = 100
list_of_ids = sample_random_clients(
    total_clients, centralized_train_config["batch_size"], federated_partition
)

federated_client_generator: Callable[[str], FlowerRayClient] = (
    get_flower_client_generator(
        network_generator, federated_partition, lambda seq_id: list_of_ids[seq_id]
    )
)
# Out:
# INFO flwr 2025-02-07 12:59:46,525 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 12:59:46,538 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 12:59:46,541 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 12:59:46,543 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 12:59:46,546 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 12:59:46,547 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 12:59:46,549 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 12:59:46,550 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 12:59:46,552 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 12:59:46,555 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 12:59:46,557 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 12:59:46,558 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 12:59:46,560 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 12:59:46,562 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 12:59:46,566 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 12:59:46,567 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 12:59:46,569 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-07 12:59:46,571 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 12:59:46,572 | 2290543087.py:21 | cid: 2688
# INFO flwr 2025-02-07 12:59:46,574 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 12:59:46,576 | 2290543087.py:21 | cid: 447
# INFO flwr 2025-02-07 12:59:46,578 | 2290543087.py:21 | cid: 1742
# INFO flwr 2025-02-07 12:59:46,580 | 2290543087.py:21 | cid: 2601
# INFO flwr 2025-02-07 12:59:46,581 | 2290543087.py:21 | cid: 1633
# INFO flwr 2025-02-07 12:59:46,582 | 2290543087.py:21 | cid: 267

    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

test_config: dict[str, Any] = {
    "batch_size": 32,
    "num_workers": 0,
    "max_batches": 100,
}

# %%
num_clients = 4
clients = random.sample(list(range(total_clients)), num_clients)

# %%
trained_models = [
    fit_client_seeded(
        federated_client_generator(str(cid)), seed_model_params, one_epoch_config
    )
    for cid in clients
]
# Out:
# INFO flwr 2025-02-07 15:11:46,710 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 15:11:46,882 | 2290543087.py:21 | cid: 51
# INFO flwr 2025-02-07 15:11:47,073 | 2290543087.py:21 | cid: 1668
# INFO flwr 2025-02-07 15:11:47,137 | 2290543087.py:21 | cid: 1498

# %%
trained_model_parameters = [model for model, *rest in trained_models]
trained_model_metrics = [rest for _, *rest in trained_models]
log(INFO, "Metrics from trained models are: %s", trained_model_metrics)
# Out:
# INFO flwr 2025-02-07 15:11:48,537 | 756348695.py:3 | Metrics from trained models are: [[4, {'train_loss': 0.12445169873535633}], [11, {'train_loss': 0.12350664355538109}], [3, {'train_loss': 0.12321196496486664}], [4, {'train_loss': 0.1236396823078394}]]

# %% [markdown]
# ---
#
# **Question 5 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
# If we index the weights of an ML model consecutively, with the assumed architecture being the same, we can visualize it as a single flattened 1-D vector. One, highly imperfect, metric for determining how similar two ML models are is cosine similarity. We can use this metric to compare the models our clients produce are.
#
# 1. Write functions to:
#     - Flatten the `NDArrays` objects into a single 1-D vector.
#     - Compute the cosine similarity of two 1-D vectors based on their inner product and norms.
# 2. Compute a similarity matrix between all client models and plot it.
# 3. What happens to the similarity matrix if you increase the number of local epochs that clients train for to 5 from 1? Why do you think that is?
# >You may want to save the parameters calculated here separately from the deault ones as both sets will be needed in future questions.
#
# ---
#
# **Question 6 (Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
# One reason that cosine similarity is an imperfect metric is because it considers weights from different layers to be equally important to the model in terms of its behavior and performance. We can thus create a slightly more detailed picture by tracking the cosine similarity across layers.
#
# 1. Create a function which computes the pairwise cosine similarity between flattened model layers across clients, i.e. the cosine similarity between the flattened $l_i$ in `client_x` and the flattened $l_i$ in `client_y`.
# 2. Plot the similarity of the models at each layer between the most similar client pair and the most disimilar client pair (as determined by the multi-epoch experiment) using the **one-epoch models**, how do the curves you observe relate to the general cosine similarity you computed for the flattened models.
# 3. What happens to the curves if you increase the number of local epochs to 5? How does this behavior relate to what you observed in the previous exercise ?
# 4. **Optional**: Do you think there is any connection to the underlying architecture? Why? Repeat the above experiments using an MLP such as the one provided by the  `get_network_generator_mlp` in `client_utils` and compare results against the CNN.
#
# ---

# %% [markdown]
# ### Question 5
# Flattening the arrays and computing cosine similarity is very straightforward, and is shown in the code below. The similarity matrix is computed using the cos_similarity function. To make plotting easier, the data (model params) is converted to pandas DataFrames first, and the plotting is done using seaborn.

# %%
from numpy import dot
from numpy.linalg import norm
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

def flatten_array(arrays):
    params = np.concatenate([a.ravel() for a in arrays])
    return params


def cos_similarity(vec1, vec2):
    return dot(vec1, vec2) / (norm(vec1) * norm(vec2))

def plot_similarity(all_model_params):
    n_models = len(all_model_params)
    flattened_params = pd.DataFrame([flatten_array(a) for a in all_model_params])
    similarity = pdist(flattened_params, cos_similarity)
    similarity_matrix = pd.DataFrame(squareform(similarity), columns=range(n_models), index=range(n_models))
    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(similarity_matrix, annot=True,  ax=ax)

# %%
plot_similarity(trained_model_parameters)

# %% [markdown]
# For question 5, we now try to increase the number of epochs to 5:

# %%
five_epoch_config: dict[str, Any] = {
    "epochs": 5,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

trained_models_five_epochs = [
    fit_client_seeded(
        federated_client_generator(str(cid)), seed_model_params, five_epoch_config
    )
    for cid in clients
]

trained_model_parameters_five_epochs = [model for model, *rest in trained_models_five_epochs]
trained_model_metrics_five_epochs = [rest for _, *rest in trained_models_five_epochs]
log(INFO, "Metrics from trained models are: %s", trained_model_metrics_five_epochs)

plot_similarity(trained_model_parameters_five_epochs)
# Out:
# INFO flwr 2025-02-07 15:11:54,672 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 15:11:54,879 | 2290543087.py:21 | cid: 51
# INFO flwr 2025-02-07 15:11:55,700 | 2290543087.py:21 | cid: 1668
# INFO flwr 2025-02-07 15:11:55,916 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 15:11:56,109 | 1278076779.py:19 | Metrics from trained models are: [[4, {'train_loss': 0.10080713406205177}], [11, {'train_loss': 0.10983954099091617}], [3, {'train_loss': 0.10798138131697972}], [4, {'train_loss': 0.0967910923063755}]]

# %% [markdown]
# We see that, when training for 5 epochs, the models have a lower cosine similarity. This is likely because they have been trained on different data, so their parameters have been fitted more, but in different directions (e.g., one client could have trained to classify only two of the classes, if its local dataset only contains these). Recall that before training, the models are initialized with the same initialization function and the same random seed, which means their initial params should be identical, and that training for fewer epochs should then mean that they remain quite close together.

# %% [markdown]
# ### Question 6

# %%
def pairwise_similarity(model_1, model_2):
    n_layers = len(model_1)
    flattened_params_1 = [flatten_array(layer) for layer in model_1]
    flattened_params_2 = [flatten_array(layer) for layer in model_2]
    similarity = []
    for i in range(n_layers):
        similarity.append(cos_similarity(flattened_params_1[i], flattened_params_2[i]))

    x_values = np.arange(n_layers)
    fig, ax = plt.subplots(figsize=(6,6))
    sns.set(style='whitegrid')
    sns.lineplot(x=x_values, y=similarity)

# Two most similar:
pairwise_similarity(trained_model_parameters[2], trained_model_parameters[3])

# Two most dissimilar:
pairwise_similarity(trained_model_parameters[0], trained_model_parameters[1])

# %% [markdown]
# The curves show that the similarity between individual layers varies alot throughout the model, with some layers being very similar (0.95) and others being further apart(down to 0.72 in the model trained for 1 epoch).
#
# Between the two comparisons, we still see that the first curve (two most similar models) has an overall better similarity across layers compared to the second one, while the second curve (dissimilar models) varies alot from layer to layer, with some layers being very close and others quite far apart.
#
# We now repeat the experiment for the trained model params that went through 5 epochs:

# %%
# For 5 epochs:
# Two most similar:
pairwise_similarity(trained_model_parameters_five_epochs[0], trained_model_parameters_five_epochs[2])

# Two most dissimilar:
pairwise_similarity(trained_model_parameters_five_epochs[1], trained_model_parameters_five_epochs[3])

# %% [markdown]
# We see that the overall similarity between layers is much more consistent, which is expected since we trained it for longer. However, there is still quite a lot of variation between the layers. Interestingly, the first two layers of the model are consistently very similar between all models.

# %%
from numpy import dot
from numpy.linalg import norm
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

def flatten_array(arrays):
    params = np.concatenate([a.ravel() for a in arrays])
    return params


def cos_similarity(vec1, vec2):
    return dot(vec1, vec2) / (norm(vec1) * norm(vec2))

def plot_similarity(all_model_params):
    n_models = len(all_model_params)
    flattened_params = pd.DataFrame([flatten_array(a) for a in all_model_params])
    similarity = pdist(flattened_params, cos_similarity)
    similarity_matrix = pd.DataFrame(squareform(similarity), columns=range(n_models), index=range(n_models))
    fig, ax = plt.subplots(figsize=(6,6))
    sns.heatmap(similarity_matrix, annot=True,  ax=ax)

# %% [markdown]
# ## 7. Federated training with Flower
# ---

# %% [markdown]
# The two basic blocks of synchronous server-client FL systems are:
# - A client with some local training method and data---i.e., SGD. This is what we have built thus far.
# - A server which coordinates training sends the federated model to clients at the start of each round and aggregates model updates at the end of each round.

# %% [markdown]
# ![picture](https://drive.google.com/uc?id=1Db_Uys2QPFHW6cMranZ_QXo2vC0A_C-N)

# %% [markdown]
# While the variety of client local training methods is as wide as ML, server training varies depending on which **aggregation algorithm** combines the model updates and forms the new federated model. Flower refers to the component that controls the aggregation and train/test configuration as a **strategy**. For our labs, strategy and aggregation algorithms will be used interchangeably.
#
# The strategy we shall use is [FedAvg](https://arxiv.org/abs/1602.05629):
#
# $G^{r+1} = G^{r} + \eta \left( \sum_{k=1}^{m} p_k G^r_k \right)$,
#
# where $G^{r+1}$ is the model for the next round, which is formed by applying a model update to the current round model $G^{r}$ weighted by the aggregation learning rate $\eta$. The model update is constructed by a sum of client models $G^{r}_k$ where each client model is weighted by $p_k$. The weight factor is usually set to $p_k = \tfrac{n_k}{N}$---the number of training examples held by said client divided by the example count of each client in the round $N = \sum_{k=1}^{m} n_k$.

# %% [markdown]
# ---
#
# **Question 7 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
# Averaging models is meant to provide us with a reasonable compromise between the desired models of all clients involved. Given what you already know about the similarity of client models, we can test if this is true.
# 1. Write a function to compute the weighted average of two `NDArrays` objects while preserving the layer-structure. Use the FedAvg equation above with $p_k = \tfrac{n_k}{N}$.
# 2. Compute the average model of the client models above, both the one-epoch and multi-epoch ones.
# 3. Add the averaged models to the cosine-similarity matrices built above, how does it relate to the client models?
#
# ---
#
# **Question 8 (Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
#
# 1. Repeat the procedure above but for layer-wise cosine similarity and plot the cosine similarity of the two clients client most similar and most disimillar to the averaged model (as determined by the five-epoch condition) using the one-epoch models.
# 2. How does the relationship change for the higher-epoch condition?
#
# ---

# %%
# Question 7
def weighted_avg(arr1, arr2, n1, n2):
    # compute weighting
    p1 = n1 / (n1 + n2)
    p2 = n2 / (n1 + n2)
    output = []
    for i in range(len(arr1)):
        layer = (arr1[i] * p1) + (arr2[i] * p2)
        output.append(layer)
    return output

def get_avg_model(params, data):
    # continue averaging until there is only 1 model left.
    all_model_params = params.copy()
    all_model_data = data.copy()
    while len(all_model_params) > 1:
        model1, count1 = all_model_params.pop(0), all_model_data.pop(0)[0]
        model2, count2 = all_model_params.pop(0), all_model_data.pop(0)[0]
        avg_params = weighted_avg(model1, model2, count1, count2)
        all_model_params.append(avg_params)
        all_model_data.append([count1 + count2])
    
    return all_model_params[0], all_model_data[0]

# get avg model from 1 epoch:
avg_model_1, _ = get_avg_model(trained_model_parameters, trained_model_metrics)

# get avg model from 5 epoch:
avg_model_5, _ = get_avg_model(trained_model_parameters_five_epochs, trained_model_metrics_five_epochs)

# add avg model to all models and plot them
trained_and_avg_model_parameters = trained_model_parameters + [avg_model_1]
trained_and_avg_model_parameters_five = trained_model_parameters_five_epochs + [avg_model_5]

# plot all similarities, where the last model (index 4) is the new avg model
plot_similarity(trained_and_avg_model_parameters)
plot_similarity(trained_and_avg_model_parameters_five)
# Out:
# [[4, {'train_loss': 0.12445169873535633}], [11, {'train_loss': 0.12350664355538109}], [3, {'train_loss': 0.12321196496486664}], [4, {'train_loss': 0.1236396823078394}]]

# %% [markdown]
# We see that the new avg models are quite dissimilar to all of the input models, but they have approximately the same cosine similarity to all the models. We see that the similarity is the highest between client 1 and the average, which is expected, since that client has more data than the others (11, while the others have 4, 3, and 4, respectively), meaning that client 1 has a greater influence on the average model.

# %% [markdown]
# ### Question 8

# %%
# For 1 epoch:
# Two most similar:
pairwise_similarity(trained_and_avg_model_parameters[1], trained_and_avg_model_parameters[4])

# Two most dissimilar:
pairwise_similarity(trained_and_avg_model_parameters[0], trained_and_avg_model_parameters[4])

# %%
# For 5 epochs:
# Two most similar:
pairwise_similarity(trained_and_avg_model_parameters_five[1], trained_and_avg_model_parameters_five[4])

# Two most dissimilar:
pairwise_similarity(trained_and_avg_model_parameters_five[0], trained_and_avg_model_parameters_five[4])

# %% [markdown]
# We see that the model which has trained for 5 epochs has a greater variation in similarity between layers compared to the model trained for 1 epoch. However, the similarity is a lot higher than the previous comparison (non-averaged models), showing that the averaged models are overall more similar in more of the layers.

# %% [markdown]
# The pieces necessary for starting an FL simulation are now in play; we need to arrange them to fit the Flower API. First, we shall require a separate federated evaluation function which can be called outside the context of a specific client. It will use the centralised test set to be as simple as possible.

# %%
def get_federated_evaluation_function(
    batch_size: int,
    num_workers: int,
    model_generator: Callable[[], Module],
    criterion: Module,
    max_batches: int,
) -> Callable[[int, NDArrays, dict[str, Any]], tuple[float, dict[str, Scalar]]]:
    """Wrap the external federated evaluation function.

    It provides the external federated evaluation function with some
    parameters for the dataloader, the model generator function, and
    the criterion used in the evaluation.

    Parameters
    ----------
        batch_size (int): batch size of the test set to use.
        num_workers (int): correspond to `num_workers` param in the Dataloader object.
        model_generator (Callable[[], Module]):  model generator function.
        criterion (Module): PyTorch Module containing the criterion for evaluating the
        model.

    Returns
    -------
        Callable[[int, NDArrays, dict[str, Any]], tuple[float, dict[str, Scalar]]]:
            external federated evaluation function.
    """

    def federated_evaluation_function(
        server_round: int,
        parameters: NDArrays,
        fed_eval_config: dict[
            str, Any
        ],  # mandatory argument, even if it's not being used
    ) -> tuple[float, dict[str, Scalar]]:
        """Evaluate federated model on the server.

        It uses the centralized val set for sake of simplicity.

        Parameters
        ----------
            server_round (int): current federated round.
            parameters (NDArrays): current model parameters.
            fed_eval_config (dict[str, Any]): mandatory argument in Flower, can contain
                some configuration info

        Returns
        -------
            tuple[float, dict[str, Scalar]]: evaluation results
        """
        device: str = get_device()
        net: Module = set_model_parameters(model_generator(), parameters)
        net.to(device)

        full_file: Path = centralized_mapping
        dataset: Dataset = load_femnist_dataset(data_dir, full_file, "val")

        valid_loader = DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=False,
            num_workers=num_workers,
            drop_last=False,
        )

        loss, acc = test_femnist(
            net=net,
            test_loader=valid_loader,
            device=device,
            criterion=criterion,
            max_batches=max_batches,
        )
        return loss, {"accuracy": acc}

    return federated_evaluation_function


federated_evaluation_function = get_federated_evaluation_function(
    batch_size=test_config["batch_size"],
    num_workers=test_config["num_workers"],
    model_generator=network_generator,
    criterion=nn.CrossEntropyLoss(),
    max_batches=test_config["max_batches"],
)

# %%
def aggregate_weighted_average(metrics: list[tuple[int, dict]]) -> dict:
    """Combine results from multiple clients following training or evaluation.

    Parameters
    ----------
        metrics (list[tuple[int, dict]]): collected clients metrics

    Returns
    -------
        dict: result dictionary containing the aggregate of the metrics passed.
    """
    average_dict: dict = defaultdict(list)
    total_examples: int = 0
    for num_examples, metrics_dict in metrics:
        for key, val in metrics_dict.items():
            if isinstance(val, numbers.Number):
                average_dict[key].append((num_examples, val))
        total_examples += num_examples
    return {
        key: {
            "avg": float(
                sum([num_examples * metric for num_examples, metric in val])
                / float(total_examples)
            ),
            "all": val,
        }
        for key, val in average_dict.items()
    }

# %%
# Federated configuration dictionary
federated_train_config: dict[str, Any] = {
    "epochs": 5,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

# %% [markdown]
# The only challenge left is the FL simulation itself. In `Flower`, a `Server` object handles this for us by using `Ray` and spawning many heavyweight worker process.
#
# Given the limited-resource scenario in which we find ourselves, we provide you with a slightly modified simulation function which uses a simple thread pool. Feel free to swap it out for the original simulation or replace it with your own implementation if so inclined.
#
# > The server we use is not the default `Flower` server as it returns the model parameters from every single round in a `(round, NDArrays)` tuple.

# %%
def start_seeded_simulation(
    client_fn: Callable[[str], Client],
    num_clients: int,
    config: ServerConfig,
    strategy: Strategy,
    name: str,
    return_all_parameters: bool = False,
    seed: int = Seeds.DEFAULT,
    iteration: int = 0,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Wrap to seed client selection."""
    np.random.seed(seed ^ iteration)
    torch.manual_seed(seed ^ iteration)
    random.seed(seed ^ iteration)
    parameter_list, hist = flwr.simulation.start_simulation_no_ray(
        client_fn=client_fn,
        num_clients=num_clients,
        client_resources={},
        config=config,
        strategy=strategy,
    )
    save_history(home_dir, hist, name)
    return parameter_list, hist

# %%
num_rounds = 50

num_total_clients = 20

num_evaluate_clients = 0
num_clients_per_round = 5

initial_parameters = ndarrays_to_parameters(seed_model_params)


def run_simulation(
    # How long the FL process runs for:
    num_rounds: int = num_rounds,
    # Number of clients available
    num_total_clients: int = num_total_clients,
    # Number of clients used for train/eval
    num_clients_per_round: int = num_clients_per_round,
    num_evaluate_clients: int = num_evaluate_clients,
    # If less clients are overall available stop FL
    min_available_clients: int = num_total_clients,
    # If less clients are available for fit/eval stop FL
    min_fit_clients: int = num_clients_per_round,
    min_evaluate_clients: int = num_evaluate_clients,
    # Function to test the federated model performance
    # external to a client instantiation
    evaluate_fn: (
        Callable[
            [int, NDArrays, dict[str, Scalar]],
            tuple[float, dict[str, Scalar]] | None,
        ]
        | None
    ) = federated_evaluation_function,
    # Functions to generate a config for client fit/evaluate
    # by-default the same config is shallow-copied to all clients in Flower
    # this version simply uses the configs defined above
    on_fit_config_fn: Callable[
        [int], dict[str, Scalar]
    ] = lambda _x: federated_train_config,
    on_evaluate_config_fn: Callable[[int], dict[str, Scalar]] = lambda _x: test_config,
    # The "Parameters" type is merely a more packed version
    # of numpy array lists, used internally by Flower
    initial_parameters: Parameters = initial_parameters,
    # If this is set to True, aggregation will work even if some clients fail
    accept_failures: bool = False,
    # How to combine the metrics dictionary returned by all clients for fit/eval
    fit_metrics_aggregation_fn: Callable | None = aggregate_weighted_average,
    evaluate_metrics_aggregation_fn: Callable | None = aggregate_weighted_average,
    federated_client_generator: Callable[
        [str], flwr.client.NumPyClient
    ] = federated_client_generator,
    # Aggregation learning rate for FedAvg
    server_learning_rate: float = 1.0,
    server_momentum: float = 0.0,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Run a federated simulation using Flower."""
    log(INFO, "FL will execute for %s rounds", num_rounds)

    # Percentage of clients used for train/eval
    fraction_fit: float = float(num_clients_per_round) / num_total_clients
    fraction_evaluate: float = float(num_evaluate_clients) / num_total_clients

    strategy = FedAvg(
        fraction_fit=fraction_fit,
        fraction_evaluate=fraction_evaluate,
        min_fit_clients=min_fit_clients,
        min_evaluate_clients=min_evaluate_clients,
        min_available_clients=min_available_clients,
        on_fit_config_fn=on_fit_config_fn,
        on_evaluate_config_fn=on_evaluate_config_fn,
        evaluate_fn=evaluate_fn,
        initial_parameters=initial_parameters,
        accept_failures=accept_failures,
        fit_metrics_aggregation_fn=fit_metrics_aggregation_fn,
        evaluate_metrics_aggregation_fn=evaluate_metrics_aggregation_fn,
        server_learning_rate=server_learning_rate,
        server_momentum=server_momentum,
    )
    # resetting the seed for the random selection of clients
    # this way the list of clients trained is guaranteed to be always the same

    cfg = ServerConfig(num_rounds)

    def simulator_client_generator(cid: str) -> Client:
        return federated_client_generator(cid).to_client()

    parameters_for_each_round, hist = start_seeded_simulation(
        client_fn=simulator_client_generator,
        num_clients=num_total_clients,
        config=cfg,
        strategy=strategy,
        name="fedavg",
        return_all_parameters=True,
        seed=Seeds.DEFAULT,
    )
    return parameters_for_each_round, hist

# %%
parameters_for_each_round, hist = run_simulation()
# Out:
# INFO flwr 2025-02-07 16:50:46,639 | 1464702590.py:56 | FL will execute for 50 rounds
# INFO flwr 2025-02-07 16:50:46,652 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=50, round_timeout=None)
# INFO flwr 2025-02-07 16:50:46,654 | server_returns_parameters.py:81 | Initializing global parameters
# INFO flwr 2025-02-07 16:50:46,660 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO flwr 2025-02-07 16:50:46,665 | server_returns_parameters.py:84 | Evaluating initial parameters
#  11%|█         | 100/891 [00:01<00:11, 67.70it/s]
# INFO flwr 2025-02-07 16:50:48,261 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 413.6842665672302, {'accuracy': 0.0065625}
# INFO flwr 2025-02-07 16:50:48,261 | server_returns_parameters.py:97 | FL starting
# DEBUG flwr 2025-02-07 16:50:48,261 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:50:48,262 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 16:50:48,263 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 16:50:48,263 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 16:50:48,263 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 16:50:48,264 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-07 16:50:49,707 | server_returns_parameters.py:237 | fit_round 1 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 148.93it/s]
# INFO flwr 2025-02-07 16:50:50,487 | server_returns_parameters.py:120 | fit progress: (1, 358.67696475982666, {'accuracy': 0.074375}, 2.225552791991504)
# INFO flwr 2025-02-07 16:50:50,487 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2025-02-07 16
| server_returns_parameters.py:237 | fit_round 10 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 160.77it/s]
# INFO flwr 2025-02-07 16:51:09,775 | server_returns_parameters.py:120 | fit progress: (10, 215.07564198970795, {'accuracy': 0.5040625}, 21.513136249996023)
# INFO flwr 2025-02-07 16:51:09,775 | server_returns_parameters.py:171 | evaluate_round 10: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:09,775 | server_returns_parameters.py:223 | fit_round 11: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:09,776 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 16:51:09,776 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 16:51:09,776 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 16:51:09,776 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 16:51:09,777 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-07 16:51:10,946 | server_returns_parameters.py:237 | fit_round 11 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 162.71it/s]
# INFO flwr 2025-02-07 16:51:11,667 | server_returns_parameters.py:120 | fit progress: (11, 182.85562831163406, {'accuracy': 0.5709375}, 23.405101624986855)
# INFO flwr 2025-02-07 16:51:11,667 | server_returns_parameters.py:171 | evaluate_round 11: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:11,668 | server_returns_parameters.py:223 | fit_round 12: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:11,668 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 16:51:11,668 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 16:51:11,669 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 16:51:11,669 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 16:51:11,669 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-07 16:51:12,872 | server_returns_parameters.py:237 | fit_round 12 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 160.44it/s]
# INFO flwr 2025-02-07 16:51:13,603 | server_returns_parameters.py:120 | fit progress: (12, 192.8424390554428, {'accuracy': 0.553125}, 25.340959332999773)
# INFO flwr 2025-02-07 16:51:13,603 | server_returns_parameters.py:171 | evaluate_round 12: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:13,603 | server_returns_parameters.py:223 | fit_round 13: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:13,603 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 16:51:13,604 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 16:51:13,605 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 16:51:13,605 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 16:51:13,605 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-07 16:51:14,961 | server_returns_parameters.py:237 | fit_round 13 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 165.60it/s]
# INFO flwr 2025-02-07 16:51:15,671 | server_returns_parameters.py:120 | fit progress: (13, 155.08834713697433, {'accuracy': 0.6059375}, 27.409479750000173)
# INFO flwr 2025-02-07 16:51:15,671 | server_returns_parameters.py:171 | evaluate_round 13: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:15,672 | server_returns_parameters.py:223 | fit_round 14: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:15,672 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 16:51:15,672 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 16:51:15,672 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 16:51:15,672 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 16:51:15,673 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-07 16:51:16,866 | server_returns_parameters.py:237 | fit_round 14 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 166.13it/s]
# INFO flwr 2025-02-07 16:51:17,576 | server_returns_parameters.py:120 | fit progress: (14, 176.79363599419594, {'accuracy': 0.598125}, 29.31405529199401)
# INFO flwr 2025-02-07 16:51:17,576 | server_returns_parameters.py:171 | evaluate_round 14: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:17,576 | server_returns_parameters.py:223 | fit_round 15: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:17,576 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 16:51:17,577 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 16:51:17,578 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 16:51:17,578 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 16:51:17,579 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-07 16:51:18,628 | server_returns_parameters.py:237 | fit_round 15 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 165.35it/s]
# INFO flwr 2025-02-07 16:51:19,342 | server_returns_parameters.py:120 | fit progress: (15, 186.11819756031036, {'accuracy': 0.58625}, 31.080661167012295)
# INFO flwr 2025-02-07 16:51:19,343 | server_returns_parameters.py:171 | evaluate_round 15: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:19,343 | server_returns_parameters.py:223 | fit_round 16: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:19,343 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 16:51:19,343 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 16:51:19,344 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 16:51:19,344 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 16:51:19,344 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-07 16:51:20,890 | server_returns_parameters.py:237 | fit_round 16 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 148.25it/s]
# INFO flwr 2025-02-07 16:51:21,677 | server_returns_parameters.py:120 | fit progress: (16, 154.4578917324543, {'accuracy': 0.63125}, 33.41574562501046)
# INFO flwr 2025-02-07 16:51:21,678 | server_returns_parameters.py:171 | evaluate_round 16: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:21,678 | server_returns_parameters.py:223 | fit_round 17: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:21,678 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 16:51:21,679 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 16:51:21,679 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 16:51:21,680 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 16:51:21,680 | 2290543087.py:21 | cid: 1603
# DEBUG flwr 2025-02-07 16:51:23,142 | server_returns_parameters.py:237 | fit_round 17 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 142.43it/s]
# INFO flwr 2025-02-07 16:51:23,951 | server_returns_parameters.py:120 | fit progress: (17, 167.34664165973663, {'accuracy': 0.6071875}, 35.68929695800762)
# INFO flwr 2025-02-07 16:51:23,951 | server_returns_parameters.py:171 | evaluate_round 17: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:23,952 | server_returns_parameters.py:223 | fit_round 18: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:23,953 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 16:51:23,953 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 16:51:23,953 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 16:51:23,953 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 16:51:23,953 | 2290543087.py:21 | cid: 1494
# DEBUG flwr 2025-02-07 16:51:25,205 | server_returns_parameters.py:237 | fit_round 18 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 155.97it/s]
# INFO flwr 2025-02-07 16:51:25,956 | server_returns_parameters.py:120 | fit progress: (18, 152.81637713313103, {'accuracy': 0.6378125}, 37.69399045800674)
# INFO flwr 2025-02-07 16:51:25,956 | server_returns_parameters.py:171 | evaluate_round 18: no clients selected, cancel
# DEBUG flwr 2025-02-07 16:51:25,957 | server_returns_parameters.py:223 | fit_round 19: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 16:51:25,957 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 16:51:25,957 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 16:51:25,957 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 16:51:25,958 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 16:51:25,958 | 2290543087.py:21 | cid: 2338
# DEBUG flwr 2025-02-07 16:51:27,439 | server_returns_parameters.py:237 | fit_round 19 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 154
| app.py:252 | app_fit: metrics_distributed {}
# INFO flwr 2025-02-07 16:52:34,614 | app.py:253 | app_fit: losses_centralized [(0, 413.6842665672302), (1, 358.67696475982666), (2, 341.18613028526306), (3, 335.51778864860535), (4, 325.23952174186707), (5, 286.4196881055832), (6, 262.02463042736053), (7, 236.43919909000397), (8, 222.62824529409409), (9, 212.6857714653015), (10, 215.07564198970795), (11, 182.85562831163406), (12, 192.8424390554428), (13, 155.08834713697433), (14, 176.79363599419594), (15, 186.11819756031036), (16, 154.4578917324543), (17, 167.34664165973663), (18, 152.81637713313103), (19, 151.1226879954338), (20, 156.05804362893105), (21, 169.085409283638), (22, 156.60106992721558), (23, 172.48416471481323), (24, 142.06365525722504), (25, 122.25651331245899), (26, 138.38100230693817), (27, 144.9590112492442), (28, 135.9652003645897), (29, 148.05708822607994), (30, 152.6748130619526), (31, 140.39941868185997), (32, 142.70585760474205), (33, 128.2078606337309), (34, 150.9686283171177), (35, 139.70085230469704), (36, 151.26403331756592), (37, 132.25273428857327), (38, 140.857050254941), (39, 134.90788108110428), (40, 170.7613832950592), (41, 149.9491267800331), (42, 132.31082558631897), (43, 146.47409249842167), (44, 131.96497955918312), (45, 179.77910190820694), (46, 151.8322180956602), (47, 161.3004084676504), (48, 144.88848195970058), (49, 146.32030031085014), (50, 182.95269176363945)]
# INFO flwr 2025-02-07 16:52:34,614 | app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.0065625), (1, 0.074375), (2, 0.079375), (3, 0.12125), (4, 0.104375), (5, 0.2375), (6, 0.341875), (7, 0.41875), (8, 0.4840625), (9, 0.514375), (10, 0.5040625), (11, 0.5709375), (12, 0.553125), (13, 0.6059375), (14, 0.598125), (15, 0.58625), (16, 0.63125), (17, 0.6071875), (18, 0.6378125), (19, 0.638125), (20, 0.614375), (21, 0.55375), (22, 0.6415625), (23, 0.57625), (24, 0.6290625), (25, 0.68625), (26, 0.6596875), (27, 0.6934375), (28, 0.658125), (29, 0.63375), (30, 0.6296875), (31, 0.6525), (32, 0.6290625), (33, 0.7075), (34, 0.60875), (35, 0.6615625), (36, 0.5953125), (37, 0.6453125), (38, 0.6790625), (39, 0.675), (40, 0.5646875), (41, 0.63625), (42, 0.6584375), (43, 0.6346875), (44, 0.6775), (45, 0.5721875), (46, 0.6684375), (47, 0.6465625), (48, 0.67125), (49, 0.6390625), (50, 0.6109375)]}

# %%
log(
    INFO,
    "Size of the list with the model parameters: %s",
    len(parameters_for_each_round),
)
# Out:
# INFO flwr 2025-02-07 16:55:50,064 | 1532827960.py:1 | Size of the list with the model parameters: 51

# %% [markdown]
# ---
#
# **Question 9 (Part II ✅ | Part III/MPhil ✅):**
#
# (You must provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# Now that an entire FL experiment can be trained, it is worth considering the relationship between the FL model across rounds. If we consider the final model $\theta^N$ obtained after $N$ rounds to be the optimal model $\theta^*$, we can ask how optimization step contributed to reaching $\theta^*$.
#
# 1. Run an FL simulation for at-least 50 rounds.
# 2. Build a function which reconstitutes the update that must have been applied to model $\theta^t$ in order to obtain $\theta^{t+1}$, assume the `server_learning_rate` was 1.0. We shall call this update $g_t$ and treat it as a pseudo-gradient.
# 3. For each round plot the cosine similarity between $g_t$ and the direction of improvement towards $\theta^{*}$ calculated as $\theta^{*} - \theta_t$.
# 4. What do you observe from the plots? Does every update point in the direction of the final model? If not, why do you think that is?
#
# ---
#
# **Question 10 (Part III/MPhil ✅):**
#
# (You must provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
#  and then for
#
# 1.   Read about server momentum in FL [here](https://arxiv.org/abs/2003.00295) and repeat the previous experiments using `server_learning_rate=1.0` and `server_momentum=0.9`. Discuss how the momentum impacts the direction of optimization.
#
# ---

# %%
def get_pseudo_gradient(param_t, param_next):
    output_gradients = []
    for i in range(len(param_t)):
        output_gradients.append(param_next[i] - param_t[i])
    return output_gradients

# %%
def cos_similarity_between_all_rounds(all_rounds_params):
    cos_similarities = []
    _, params_final = all_rounds_params[-1]
    for i in range(len(all_rounds_params) - 1):
        _, params = all_rounds_params[i]
        _, params_next = all_rounds_params[i + 1]

        # compute gradients
        pseudo_gradient = get_pseudo_gradient(params, params_next)
        dir_towards_final_model = get_pseudo_gradient(params, params_final)

        # compute cos similarity
        flattened_grad = flatten_array(pseudo_gradient)
        flattened_dir = flatten_array(dir_towards_final_model)
        similarity = cos_similarity(flattened_grad, flattened_dir)
        cos_similarities.append(similarity)
    
    return cos_similarities

cos_similarities = cos_similarity_between_all_rounds(parameters_for_each_round)

x_values = np.arange(len(parameters_for_each_round) - 1)
fig, ax = plt.subplots(figsize=(6,6))
sns.set(style='whitegrid')
sns.lineplot(x=x_values, y=cos_similarities)
# Out:
# <Axes: >

# %% [markdown]
# We find that the updates per round get closer during training, although there is a long plateau between round 15 and round 45 where the updates sometimes move in the slightly wrong direction. During these many updates in the middle, the model accuracy is plateauing, which means that every update does not necessarily move far in the direction of a better model, but is simply adapting to fit the observed data slightly better. Since the 'optimal' model is also a result of these small adjustments, it makes sense that not every adjustment is moving perfectly in its direction. Rather, we only see the last few rounds moving directly towards the final model. This is not because the final few rounds make a big difference in terms of loss, but because these last rounds are the ones that are the closest to what we call the final 'optimal' model.

# %% [markdown]
# ### Question 9

# %%
parameters_for_each_round_momentum, hist_momentum = run_simulation(server_momentum=0.9)
# Out:
# INFO flwr 2025-02-07 17:50:19,896 | 1464702590.py:56 | FL will execute for 50 rounds
# INFO flwr 2025-02-07 17:50:19,903 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=50, round_timeout=None)
# INFO flwr 2025-02-07 17:50:19,904 | server_returns_parameters.py:81 | Initializing global parameters
# INFO flwr 2025-02-07 17:50:19,914 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO flwr 2025-02-07 17:50:19,917 | server_returns_parameters.py:84 | Evaluating initial parameters
#  11%|█         | 100/891 [00:01<00:11, 69.38it/s]
# INFO flwr 2025-02-07 17:50:21,476 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 413.6842665672302, {'accuracy': 0.0065625}
# INFO flwr 2025-02-07 17:50:21,476 | server_returns_parameters.py:97 | FL starting
# DEBUG flwr 2025-02-07 17:50:21,476 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:21,477 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:50:21,477 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:50:21,478 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:50:21,478 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:50:21,478 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-07 17:50:22,912 | server_returns_parameters.py:237 | fit_round 1 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 156.07it/s]
# INFO flwr 2025-02-07 17:50:23,663 | server_returns_parameters.py:120 | fit progress: (1, 361.55588459968567, {'accuracy': 0.074375}, 2.1863522089843173)
# INFO flwr 2025-02-07 17:50:23,663 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:23,663 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:23,664 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:50:23,664 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:50:23,665 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:50:23,665 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:50:23,666 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-07 17:50:24,889 | server_returns_parameters.py:237 | fit_round 2 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 157.16it/s]
# INFO flwr 2025-02-07 17:50:25,639 | server_returns_parameters.py:120 | fit progress: (2, 500.2706689834595, {'accuracy': 0.0965625}, 4.162417958985316)
# INFO flwr 2025-02-07 17:50:25,639 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:25,639 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:25,640 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:50:25,641 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 17:50:25,641 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:50:25,641 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:50:25,641 | 2290543087.py:21 | cid: 2907
# DEBUG flwr 2025-02-07 17:50:26,949 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 158.04it/s]
# INFO flwr 2025-02-07 17:50:27,688 | server_returns_parameters.py:120 | fit progress: (3, 358.40403604507446, {'accuracy': 0.0884375}, 6.211905042000581)
# INFO flwr 2025-02-07 17:50:27,688 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:27,689 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:27,689 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-07 17:50:27,689 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:50:27,689 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:50:27,690 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:50:27,690 | 2290543087.py:21 | cid: 1363
# DEBUG flwr 2025-02-07 17:50:28,822 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 161.34it/s]
# INFO flwr 2025-02-07 17:50:29,550 | server_returns_parameters.py:120 | fit progress: (4, 341.6076126098633, {'accuracy': 0.0721875}, 8.073957083979622)
# INFO flwr 2025-02-07 17:50:29,551 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:29,551 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:29,551 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:50:29,552 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:50:29,552 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 17:50:29,553 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:50:29,553 | 2290543087.py:21 | cid: 678
# DEBUG flwr 2025-02-07 17:50:30,852 | server_returns_parameters.py:237 | fit_round 5 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 155.25it/s]
# INFO flwr 2025-02-07 17:50:31,604 | server_returns_parameters.py:120 | fit progress: (5, 386.48018288612366, {'accuracy': 0.040625}, 10.127187874983065)
# INFO flwr 2025-02-07 17:50:31,604 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:31,604 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:31,605 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:50:31,605 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:50:31,607 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:50:31,607 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 17:50:31,608 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-07 17:50:32,777 | server_returns_parameters.py:237 | fit_round 6 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 161.88it/s]
# INFO flwr 2025-02-07 17:50:33,501 | server_returns_parameters.py:120 | fit progress: (6, 565.8231210708618, {'accuracy': 0.1953125}, 12.024554999981774)
# INFO flwr 2025-02-07 17:50:33,501 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:33,502 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:33,502 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:50:33,502 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:50:33,503 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-07 17:50:33,504 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:50:33,504 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-07 17:50:34,598 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 161.92it/s]
# INFO flwr 2025-02-07 17:50:35,321 | server_returns_parameters.py:120 | fit progress: (7, 471.4497902393341, {'accuracy': 0.12375}, 13.844067500001984)
# INFO flwr 2025-02-07 17:50:35,321 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:35,321 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:35,322 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:50:35,323 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:50:35,323 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:50:35,323 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:50:35,323 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-07 17:50:36,851 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 147.13it/s]
# INFO flwr 2025-02-07 17:50:37,637 | server_returns_parameters.py:120 | fit progress: (8, 340.8493285179138, {'accuracy': 0.0765625}, 16.160515708994353)
# INFO flwr 2025-02-07 17:50:37,637 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:37,638 | server_returns_parameters.py:223 | fit_round 9: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:37,638 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 17:50:37,639 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:50:37,639 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:50:37,639 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:50:37,639 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-07 17:50:38,830 | server_returns_parameters.py:237 | fit_round 9 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 163.74it/s]
# INFO flwr 2025-02-07 17:50:39,547 | server_returns_parameters.py:120 | fit progress: (9, 344.1057827472687, {'accuracy': 0.079375}, 18.07000108397915)
# INFO flwr 2025-02-07 17:50:39,547 | server_returns_parameters.py:171 | evaluate_round 9: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:39,547 | server_returns_parameters.py:223 | fit_round 10: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:39,548 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:50:39,548 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:50:39,548 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:50:39,549 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:50:39,549 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-07 17:50:41,086 | server_returns_parameters.py:237 | fit_round 10 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 162.86it/s]
# INFO flwr 2025-02-07 17:50:41,807 | server_returns_parameters.py:120 | fit progress: (10, 344.6642482280731, {'accuracy': 0.0640625}, 20.330230624997057)
# INFO flwr 2025-02-07 17:50:41,807 | server_returns_parameters.py:171 | evaluate_round 10: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:41,808 | server_returns_parameters.py:223 | fit_round 11: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:41,808 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:50:41,808 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:50:41,809 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:50:41,809 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:50:41,810 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-07 17:50:43,095 | server_returns_parameters.py:237 | fit_round 11 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 162.91it/s]
# INFO flwr 2025-02-07 17:50:43,815 | server_returns_parameters.py:120 | fit progress: (11, 343.42808961868286, {'accuracy': 0.0709375}, 22.338552542001707)
# INFO flwr 2025-02-07 17:50:43,816 | server_returns_parameters.py:171 | evaluate_round 11: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:43,816 | server_returns_parameters.py:223 | fit_round 12: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:43,816 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:50:43,817 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:50:43,818 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:50:43,818 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:50:43,818 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-07 17:50:44,842 | server_returns_parameters.py:237 | fit_round 12 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 157.17it/s]
# INFO flwr 2025-02-07 17:50:45,585 | server_returns_parameters.py:120 | fit progress: (12, 343.1178662776947, {'accuracy': 0.0709375}, 24.108053333999123)
# INFO flwr 2025-02-07 17:50:45,585 | server_returns_parameters.py:171 | evaluate_round 12: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:45,585 | server_returns_parameters.py:223 | fit_round 13: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:45,586 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:50:45,586 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:50:45,586 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:50:45,586 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 17:50:45,587 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-07 17:50:46,927 | server_returns_parameters.py:237 | fit_round 13 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 165.17it/s]
# INFO flwr 2025-02-07 17:50:47,640 | server_returns_parameters.py:120 | fit progress: (13, 344.5231649875641, {'accuracy': 0.070625}, 26.163068875001045)
# INFO flwr 2025-02-07 17:50:47,640 | server_returns_parameters.py:171 | evaluate_round 13: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:47,641 | server_returns_parameters.py:223 | fit_round 14: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:47,641 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:50:47,641 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 17:50:47,641 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:50:47,643 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:50:47,643 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-07 17:50:48,808 | server_returns_parameters.py:237 | fit_round 14 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:04, 160.75it/s]
# INFO flwr 2025-02-07 17:50:49,539 | server_returns_parameters.py:120 | fit progress: (14, 347.6397395133972, {'accuracy': 0.069375}, 28.062222666980233)
# INFO flwr 2025-02-07 17:50:49,539 | server_returns_parameters.py:171 | evaluate_round 14: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:49,540 | server_returns_parameters.py:223 | fit_round 15: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:49,540 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:50:49,540 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:50:49,540 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:50:49,542 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 17:50:49,542 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-07 17:50:50,712 | server_returns_parameters.py:237 | fit_round 15 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 152.24it/s]
# INFO flwr 2025-02-07 17:50:51,475 | server_returns_parameters.py:120 | fit progress: (15, 351.346706867218, {'accuracy': 0.079375}, 29.998294583987445)
# INFO flwr 2025-02-07 17:50:51,476 | server_returns_parameters.py:171 | evaluate_round 15: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:51,476 | server_returns_parameters.py:223 | fit_round 16: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:51,476 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:50:51,477 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 17:50:51,477 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:50:51,477 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:50:51,478 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-07 17:50:52,912 | server_returns_parameters.py:237 | fit_round 16 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 151.16it/s]
# INFO flwr 2025-02-07 17:50:53,680 | server_returns_parameters.py:120 | fit progress: (16, 352.8708539009094, {'accuracy': 0.079375}, 32.20283324999036)
# INFO flwr 2025-02-07 17:50:53,680 | server_returns_parameters.py:171 | evaluate_round 16: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:53,680 | server_returns_parameters.py:223 | fit_round 17: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:53,681 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:50:53,681 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:50:53,681 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 17:50:53,682 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:50:53,682 | 2290543087.py:21 | cid: 1603
# DEBUG flwr 2025-02-07 17:50:54,996 | server_returns_parameters.py:237 | fit_round 17 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 140.65it/s]
# INFO flwr 2025-02-07 17:50:55,813 | server_returns_parameters.py:120 | fit progress: (17, 352.3357708454132, {'accuracy': 0.079375}, 34.33620249998057)
# INFO flwr 2025-02-07 17:50:55,814 | server_returns_parameters.py:171 | evaluate_round 17: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:55,814 | server_returns_parameters.py:223 | fit_round 18: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:55,814 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:50:55,815 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:50:55,815 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:50:55,816 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:50:55,816 | 2290543087.py:21 | cid: 1494
# DEBUG flwr 2025-02-07 17:50:57,067 | server_returns_parameters.py:237 | fit_round 18 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 140.95it/s]
# INFO flwr 2025-02-07 17:50:57,883 | server_returns_parameters.py:120 | fit progress: (18, 351.6669955253601, {'accuracy': 0.079375}, 36.40558537497418)
# INFO flwr 2025-02-07 17:50:57,883 | server_returns_parameters.py:171 | evaluate_round 18: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:57,883 | server_returns_parameters.py:223 | fit_round 19: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:57,884 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:50:57,884 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 17:50:57,885 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:50:57,885 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:50:57,886 | 2290543087.py:21 | cid: 2338
# DEBUG flwr 2025-02-07 17:50:59,184 | server_returns_parameters.py:237 | fit_round 19 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 154.96it/s]
# INFO flwr 2025-02-07 17:50:59,936 | server_returns_parameters.py:120 | fit progress: (19, 351.9128863811493, {'accuracy': 0.079375}, 38.45860424998682)
# INFO flwr 2025-02-07 17:50:59,936 | server_returns_parameters.py:171 | evaluate_round 19: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:50:59,937 | server_returns_parameters.py:223 | fit_round 20: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:50:59,937 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:50:59,938 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:50:59,939 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:50:59,939 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 17:50:59,939 | 2290543087.py:21 | cid: 2399
# DEBUG flwr 2025-02-07 17:51:01,491 | server_returns_parameters.py:237 | fit_round 20 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 125.85it/s]
# INFO flwr 2025-02-07 17:51:02,392 | server_returns_parameters.py:120 | fit progress: (20, 353.43476462364197, {'accuracy': 0.069375}, 40.91505949999555)
# INFO flwr 2025-02-07 17:51:02,393 | server_returns_parameters.py:171 | evaluate_round 20: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:02,393 | server_returns_parameters.py:223 | fit_round 21: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:02,393 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:51:02,394 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:51:02,394 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:51:02,395 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:51:02,395 | 2290543087.py:21 | cid: 1260
# DEBUG flwr 2025-02-07 17:51:03,877 | server_returns_parameters.py:237 | fit_round 21 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 136.54it/s]
# INFO flwr 2025-02-07 17:51:04,719 | server_returns_parameters.py:120 | fit progress: (21, 357.30415177345276, {'accuracy': 0.069375}, 43.241262124996865)
# INFO flwr 2025-02-07 17:51:04,719 | server_returns_parameters.py:171 | evaluate_round 21: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:04,719 | server_returns_parameters.py:223 | fit_round 22: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:04,720 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:51:04,720 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:51:04,720 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:51:04,721 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:51:04,722 | 2290543087.py:21 | cid: 2530
# DEBUG flwr 2025-02-07 17:51:06,172 | server_returns_parameters.py:237 | fit_round 22 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 149.70it/s]
# INFO flwr 2025-02-07 17:51:06,947 | server_returns_parameters.py:120 | fit progress: (22, 360.97791814804077, {'accuracy': 0.0709375}, 45.469911708991276)
# INFO flwr 2025-02-07 17:51:06,948 | server_returns_parameters.py:171 | evaluate_round 22: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:06,948 | server_returns_parameters.py:223 | fit_round 23: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:06,948 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:51:06,949 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:51:06,949 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:51:06,950 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:51:06,950 | 2290543087.py:21 | cid: 1571
# DEBUG flwr 2025-02-07 17:51:08,585 | server_returns_parameters.py:237 | fit_round 23 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 119.64it/s]
# INFO flwr 2025-02-07 17:51:09,527 | server_returns_parameters.py:120 | fit progress: (23, 364.490483045578, {'accuracy': 0.0709375}, 48.04964754197863)
# INFO flwr 2025-02-07 17:51:09,528 | server_returns_parameters.py:171 | evaluate_round 23: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:09,528 | server_returns_parameters.py:223 | fit_round 24: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:09,528 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:51:09,529 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:51:09,529 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:51:09,529 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:51:09,529 | 2290543087.py:21 | cid: 1603
# DEBUG flwr 2025-02-07 17:51:10,805 | server_returns_parameters.py:237 | fit_round 24 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 156.36it/s]
# INFO flwr 2025-02-07 17:51:11,553 | server_returns_parameters.py:120 | fit progress: (24, 365.79721426963806, {'accuracy': 0.079375}, 50.07585666698287)
# INFO flwr 2025-02-07 17:51:11,554 | server_returns_parameters.py:171 | evaluate_round 24: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:11,554 | server_returns_parameters.py:223 | fit_round 25: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:11,554 | 2290543087.py:21 | cid: 2688
# INFO flwr 2025-02-07 17:51:11,555 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:51:11,555 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:51:11,555 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 17:51:11,555 | 2290543087.py:21 | cid: 3175
# DEBUG flwr 2025-02-07 17:51:12,752 | server_returns_parameters.py:237 | fit_round 25 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 150.91it/s]
# INFO flwr 2025-02-07 17:51:13,523 | server_returns_parameters.py:120 | fit progress: (25, 363.738721370697, {'accuracy': 0.079375}, 52.04518612497486)
# INFO flwr 2025-02-07 17:51:13,523 | server_returns_parameters.py:171 | evaluate_round 25: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:13,524 | server_returns_parameters.py:223 | fit_round 26: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:13,524 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:51:13,524 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:51:13,524 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:51:13,524 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:51:13,525 | 2290543087.py:21 | cid: 2530
# DEBUG flwr 2025-02-07 17:51:14,755 | server_returns_parameters.py:237 | fit_round 26 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 156.71it/s]
# INFO flwr 2025-02-07 17:51:15,501 | server_returns_parameters.py:120 | fit progress: (26, 361.5418028831482, {'accuracy': 0.079375}, 54.023173374996986)
# INFO flwr 2025-02-07 17:51:15,501 | server_returns_parameters.py:171 | evaluate_round 26: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:15,501 | server_returns_parameters.py:223 | fit_round 27: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:15,502 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:51:15,502 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:51:15,502 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 17:51:15,502 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:51:15,502 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-07 17:51:16,781 | server_returns_parameters.py:237 | fit_round 27 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 130.25it/s]
# INFO flwr 2025-02-07 17:51:17,705 | server_returns_parameters.py:120 | fit progress: (27, 359.5917224884033, {'accuracy': 0.079375}, 56.22769541697926)
# INFO flwr 2025-02-07 17:51:17,706 | server_returns_parameters.py:171 | evaluate_round 27: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:17,706 | server_returns_parameters.py:223 | fit_round 28: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:17,707 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 17:51:17,707 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:51:17,707 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-07 17:51:17,707 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:51:17,707 | 2290543087.py:21 | cid: 2997
# DEBUG flwr 2025-02-07 17:51:18,847 | server_returns_parameters.py:237 | fit_round 28 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 154.64it/s]
# INFO flwr 2025-02-07 17:51:19,600 | server_returns_parameters.py:120 | fit progress: (28, 358.89229917526245, {'accuracy': 0.079375}, 58.12258825000026)
# INFO flwr 2025-02-07 17:51:19,601 | server_returns_parameters.py:171 | evaluate_round 28: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:19,601 | server_returns_parameters.py:223 | fit_round 29: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:19,601 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:51:19,602 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 17:51:19,602 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:51:19,602 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:51:19,602 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-07 17:51:20,787 | server_returns_parameters.py:237 | fit_round 29 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 131.56it/s]
# INFO flwr 2025-02-07 17:51:21,655 | server_returns_parameters.py:120 | fit progress: (29, 359.51622557640076, {'accuracy': 0.079375}, 60.17713037499925)
# INFO flwr 2025-02-07 17:51:21,655 | server_returns_parameters.py:171 | evaluate_round 29: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:21,656 | server_returns_parameters.py:223 | fit_round 30: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:21,656 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:51:21,656 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:51:21,657 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:51:21,657 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:51:21,658 | 2290543087.py:21 | cid: 3175
# DEBUG flwr 2025-02-07 17:51:23,242 | server_returns_parameters.py:237 | fit_round 30 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 140.68it/s]
# INFO flwr 2025-02-07 17:51:24,070 | server_returns_parameters.py:120 | fit progress: (30, 360.3680307865143, {'accuracy': 0.079375}, 62.592285583988996)
# INFO flwr 2025-02-07 17:51:24,071 | server_returns_parameters.py:171 | evaluate_round 30: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:24,071 | server_returns_parameters.py:223 | fit_round 31: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:24,071 | 2290543087.py:21 | cid: 2688
# INFO flwr 2025-02-07 17:51:24,072 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 17:51:24,073 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 17:51:24,073 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-07 17:51:24,074 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-07 17:51:25,578 | server_returns_parameters.py:237 | fit_round 31 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 119.71it/s]
# INFO flwr 2025-02-07 17:51:26,527 | server_returns_parameters.py:120 | fit progress: (31, 361.6872646808624, {'accuracy': 0.070625}, 65.04847124998923)
# INFO flwr 2025-02-07 17:51:26,527 | server_returns_parameters.py:171 | evaluate_round 31: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:26,527 | server_returns_parameters.py:223 | fit_round 32: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:26,528 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:51:26,528 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:51:26,528 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:51:26,528 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:51:26,529 | 2290543087.py:21 | cid: 2338
# DEBUG flwr 2025-02-07 17:51:28,073 | server_returns_parameters.py:237 | fit_round 32 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 142.60it/s]
# INFO flwr 2025-02-07 17:51:28,884 | server_returns_parameters.py:120 | fit progress: (32, 362.907434463501, {'accuracy': 0.069375}, 67.40578083400032)
# INFO flwr 2025-02-07 17:51:28,884 | server_returns_parameters.py:171 | evaluate_round 32: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:28,885 | server_returns_parameters.py:223 | fit_round 33: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:28,885 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 17:51:28,885 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:51:28,886 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:51:28,886 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:51:28,886 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-07 17:51:30,098 | server_returns_parameters.py:237 | fit_round 33 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 154.37it/s]
# INFO flwr 2025-02-07 17:51:30,854 | server_returns_parameters.py:120 | fit progress: (33, 363.48985958099365, {'accuracy': 0.069375}, 69.37542358398787)
# INFO flwr 2025-02-07 17:51:30,854 | server_returns_parameters.py:171 | evaluate_round 33: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:30,854 | server_returns_parameters.py:223 | fit_round 34: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:30,854 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:51:30,856 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:51:30,856 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:51:30,857 | 2290543087.py:21 | cid: 2688
# INFO flwr 2025-02-07 17:51:30,857 | 2290543087.py:21 | cid: 678
# DEBUG flwr 2025-02-07 17:51:32,530 | server_returns_parameters.py:237 | fit_round 34 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 132.98it/s]
# INFO flwr 2025-02-07 17:51:33,409 | server_returns_parameters.py:120 | fit progress: (34, 362.3165578842163, {'accuracy': 0.069375}, 71.93067529198015)
# INFO flwr 2025-02-07 17:51:33,409 | server_returns_parameters.py:171 | evaluate_round 34: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:33,410 | server_returns_parameters.py:223 | fit_round 35: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:33,411 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:51:33,411 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:51:33,412 | 2290543087.py:21 | cid: 1603
# INFO flwr 2025-02-07 17:51:33,413 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:51:33,414 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-07 17:51:34,783 | server_returns_parameters.py:237 | fit_round 35 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 123.09it/s]
# INFO flwr 2025-02-07 17:51:35,707 | server_returns_parameters.py:120 | fit progress: (35, 360.33272314071655, {'accuracy': 0.069375}, 74.22859554199385)
# INFO flwr 2025-02-07 17:51:35,707 | server_returns_parameters.py:171 | evaluate_round 35: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:35,708 | server_returns_parameters.py:223 | fit_round 36: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:35,708 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:51:35,709 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:51:35,709 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:51:35,709 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:51:35,710 | 2290543087.py:21 | cid: 2600
# DEBUG flwr 2025-02-07 17:51:37,558 | server_returns_parameters.py:237 | fit_round 36 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 131.08it/s]
# INFO flwr 2025-02-07 17:51:38,435 | server_returns_parameters.py:120 | fit progress: (36, 358.23461627960205, {'accuracy': 0.079375}, 76.95654129199102)
# INFO flwr 2025-02-07 17:51:38,435 | server_returns_parameters.py:171 | evaluate_round 36: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:38,436 | server_returns_parameters.py:223 | fit_round 37: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:38,436 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 17:51:38,437 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:51:38,437 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:51:38,437 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:51:38,438 | 2290543087.py:21 | cid: 1363
# DEBUG flwr 2025-02-07 17:51:39,739 | server_returns_parameters.py:237 | fit_round 37 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 144.64it/s]
# INFO flwr 2025-02-07 17:51:40,539 | server_returns_parameters.py:120 | fit progress: (37, 357.83945536613464, {'accuracy': 0.079375}, 79.06007583398605)
# INFO flwr 2025-02-07 17:51:40,539 | server_returns_parameters.py:171 | evaluate_round 37: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:40,539 | server_returns_parameters.py:223 | fit_round 38: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:40,540 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:51:40,540 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:51:40,541 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:51:40,541 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 17:51:40,541 | 2290543087.py:21 | cid: 2907
# DEBUG flwr 2025-02-07 17:51:41,669 | server_returns_parameters.py:237 | fit_round 38 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 122.21it/s]
# INFO flwr 2025-02-07 17:51:42,594 | server_returns_parameters.py:120 | fit progress: (38, 358.5328538417816, {'accuracy': 0.079375}, 81.11579891698784)
# INFO flwr 2025-02-07 17:51:42,595 | server_returns_parameters.py:171 | evaluate_round 38: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:42,595 | server_returns_parameters.py:223 | fit_round 39: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:42,595 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:51:42,596 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:51:42,597 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:51:42,597 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:51:42,598 | 2290543087.py:21 | cid: 2184
# DEBUG flwr 2025-02-07 17:51:43,983 | server_returns_parameters.py:237 | fit_round 39 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 146.57it/s]
# INFO flwr 2025-02-07 17:51:44,773 | server_returns_parameters.py:120 | fit progress: (39, 360.20058274269104, {'accuracy': 0.079375}, 83.29430545898504)
# INFO flwr 2025-02-07 17:51:44,773 | server_returns_parameters.py:171 | evaluate_round 39: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:44,774 | server_returns_parameters.py:223 | fit_round 40: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:44,774 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:51:44,774 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:51:44,774 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:51:44,774 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:51:44,776 | 2290543087.py:21 | cid: 1603
# DEBUG flwr 2025-02-07 17:51:46,146 | server_returns_parameters.py:237 | fit_round 40 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 137.92it/s]
# INFO flwr 2025-02-07 17:51:47,036 | server_returns_parameters.py:120 | fit progress: (40, 362.672554731369, {'accuracy': 0.079375}, 85.5568672499794)
# INFO flwr 2025-02-07 17:51:47,036 | server_returns_parameters.py:171 | evaluate_round 40: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:47,036 | server_returns_parameters.py:223 | fit_round 41: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:47,036 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:51:47,037 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:51:47,037 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:51:47,037 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:51:47,038 | 2290543087.py:21 | cid: 839
# DEBUG flwr 2025-02-07 17:51:48,378 | server_returns_parameters.py:237 | fit_round 41 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 152.43it/s]
# INFO flwr 2025-02-07 17:51:49,145 | server_returns_parameters.py:120 | fit progress: (41, 363.31661224365234, {'accuracy': 0.079375}, 87.666679499991)
# INFO flwr 2025-02-07 17:51:49,146 | server_returns_parameters.py:171 | evaluate_round 41: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:49,146 | server_returns_parameters.py:223 | fit_round 42: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:49,147 | 2290543087.py:21 | cid: 2338
# INFO flwr 2025-02-07 17:51:49,147 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:51:49,149 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 17:51:49,150 | 2290543087.py:21 | cid: 1473
# INFO flwr 2025-02-07 17:51:49,150 | 2290543087.py:21 | cid: 2530
# DEBUG flwr 2025-02-07 17:51:50,409 | server_returns_parameters.py:237 | fit_round 42 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 130.77it/s]
# INFO flwr 2025-02-07 17:51:51,280 | server_returns_parameters.py:120 | fit progress: (42, 361.6006336212158, {'accuracy': 0.079375}, 89.80144191699219)
# INFO flwr 2025-02-07 17:51:51,281 | server_returns_parameters.py:171 | evaluate_round 42: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:51,281 | server_returns_parameters.py:223 | fit_round 43: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:51,281 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:51:51,282 | 2290543087.py:21 | cid: 678
# INFO flwr 2025-02-07 17:51:51,282 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:51:51,282 | 2290543087.py:21 | cid: 1498
# INFO flwr 2025-02-07 17:51:51,283 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-07 17:51:52,725 | server_returns_parameters.py:237 | fit_round 43 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 150.88it/s]
# INFO flwr 2025-02-07 17:51:53,496 | server_returns_parameters.py:120 | fit progress: (43, 359.6897647380829, {'accuracy': 0.079375}, 92.0173413750017)
# INFO flwr 2025-02-07 17:51:53,496 | server_returns_parameters.py:171 | evaluate_round 43: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:53,497 | server_returns_parameters.py:223 | fit_round 44: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:53,497 | 2290543087.py:21 | cid: 3175
# INFO flwr 2025-02-07 17:51:53,498 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-07 17:51:53,498 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:51:53,498 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:51:53,498 | 2290543087.py:21 | cid: 2338
# DEBUG flwr 2025-02-07 17:51:54,714 | server_returns_parameters.py:237 | fit_round 44 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 149.78it/s]
# INFO flwr 2025-02-07 17:51:55,488 | server_returns_parameters.py:120 | fit progress: (44, 357.5814633369446, {'accuracy': 0.0709375}, 94.00937354197958)
# INFO flwr 2025-02-07 17:51:55,489 | server_returns_parameters.py:171 | evaluate_round 44: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:55,489 | server_returns_parameters.py:223 | fit_round 45: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:55,489 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:51:55,490 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:51:55,490 | 2290543087.py:21 | cid: 1363
# INFO flwr 2025-02-07 17:51:55,490 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:51:55,490 | 2290543087.py:21 | cid: 2600
# DEBUG flwr 2025-02-07 17:51:57,123 | server_returns_parameters.py:237 | fit_round 45 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 149.18it/s]
# INFO flwr 2025-02-07 17:51:57,901 | server_returns_parameters.py:120 | fit progress: (45, 356.98970198631287, {'accuracy': 0.0709375}, 96.4218861249974)
# INFO flwr 2025-02-07 17:51:57,901 | server_returns_parameters.py:171 | evaluate_round 45: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:51:57,902 | server_returns_parameters.py:223 | fit_round 46: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:51:57,902 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:51:57,902 | 2290543087.py:21 | cid: 1571
# INFO flwr 2025-02-07 17:51:57,903 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:51:57,903 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:51:57,903 | 2290543087.py:21 | cid: 2907
# DEBUG flwr 2025-02-07 17:51:59,318 | server_returns_parameters.py:237 | fit_round 46 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 149.30it/s]
# INFO flwr 2025-02-07 17:52:00,095 | server_returns_parameters.py:120 | fit progress: (46, 356.96731328964233, {'accuracy': 0.069375}, 98.61607287498191)
# INFO flwr 2025-02-07 17:52:00,095 | server_returns_parameters.py:171 | evaluate_round 46: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:52:00,096 | server_returns_parameters.py:223 | fit_round 47: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:52:00,096 | 2290543087.py:21 | cid: 2184
# INFO flwr 2025-02-07 17:52:00,096 | 2290543087.py:21 | cid: 2600
# INFO flwr 2025-02-07 17:52:00,097 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:52:00,098 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:52:00,098 | 2290543087.py:21 | cid: 1473
# DEBUG flwr 2025-02-07 17:52:01,532 | server_returns_parameters.py:237 | fit_round 47 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 146.60it/s]
# INFO flwr 2025-02-07 17:52:02,321 | server_returns_parameters.py:120 | fit progress: (47, 357.42693042755127, {'accuracy': 0.069375}, 100.84171312500257)
# INFO flwr 2025-02-07 17:52:02,321 | server_returns_parameters.py:171 | evaluate_round 47: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:52:02,322 | server_returns_parameters.py:223 | fit_round 48: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:52:02,322 | 2290543087.py:21 | cid: 2855
# INFO flwr 2025-02-07 17:52:02,322 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:52:02,323 | 2290543087.py:21 | cid: 2530
# INFO flwr 2025-02-07 17:52:02,323 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:52:02,324 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-07 17:52:03,558 | server_returns_parameters.py:237 | fit_round 48 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 157.37it/s]
# INFO flwr 2025-02-07 17:52:04,300 | server_returns_parameters.py:120 | fit progress: (48, 357.634272813797, {'accuracy': 0.079375}, 102.8212319589802)
# INFO flwr 2025-02-07 17:52:04,301 | server_returns_parameters.py:171 | evaluate_round 48: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:52:04,301 | server_returns_parameters.py:223 | fit_round 49: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:52:04,302 | 2290543087.py:21 | cid: 2997
# INFO flwr 2025-02-07 17:52:04,302 | 2290543087.py:21 | cid: 2907
# INFO flwr 2025-02-07 17:52:04,302 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:52:04,302 | 2290543087.py:21 | cid: 1494
# INFO flwr 2025-02-07 17:52:04,303 | 2290543087.py:21 | cid: 2688
# DEBUG flwr 2025-02-07 17:52:05,856 | server_returns_parameters.py:237 | fit_round 49 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 143.03it/s]
# INFO flwr 2025-02-07 17:52:06,722 | server_returns_parameters.py:120 | fit progress: (49, 357.6656217575073, {'accuracy': 0.079375}, 105.24241862498457)
# INFO flwr 2025-02-07 17:52:06,722 | server_returns_parameters.py:171 | evaluate_round 49: no clients selected, cancel
# DEBUG flwr 2025-02-07 17:52:06,723 | server_returns_parameters.py:223 | fit_round 50: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-07 17:52:06,723 | 2290543087.py:21 | cid: 3119
# INFO flwr 2025-02-07 17:52:06,724 | 2290543087.py:21 | cid: 839
# INFO flwr 2025-02-07 17:52:06,724 | 2290543087.py:21 | cid: 2399
# INFO flwr 2025-02-07 17:52:06,724 | 2290543087.py:21 | cid: 1260
# INFO flwr 2025-02-07 17:52:06,725 | 2290543087.py:21 | cid: 678
# DEBUG flwr 2025-02-07 17:52:08,299 | server_returns_parameters.py:237 | fit_round 50 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:05, 151.01it/s]
# INFO flwr 2025-02-07 17:52:09,073 | server_returns_parameters.py:120 | fit progress: (50, 358.1183171272278, {'accuracy': 0.079375}, 107.59342537500197)
# INFO flwr 2025-02-07 17:52:09,073 | server_returns_parameters.py:171 | evaluate_round 50: no clients selected, cancel
# INFO flwr 2025-02-07 17:52:09,073 | server_returns_parameters.py:150 | FL finished in 107.59404462500243
# INFO flwr 2025-02-07 17:52:09,074 | app.py:250 | app_fit: losses_distributed []
# INFO flwr 2025-02-07 17:52:09,074 | app.py:251 | app_fit: metrics_distributed_fit {'train_loss': [(1, {'avg': 0.1034726897875468, 'all': [(4, 0.10312720574438572), (4, 0.10076603479683399), (5, 0.10478118658065796), (4, 0.10360623709857464), (4, 0.10475566051900387)]}), (2, {'avg': 0.10355677704016368, 'all': [(5, 0.10477423518896103), (4, 0.10018818639218807), (5, 0.10334885120391846), (4, 0.10532239265739918), (3, 0.10401152322689693)]}), (3, {'avg': 0.10462098258237044, 'all': [(8, 0.11468545533716679), (5, 0.09980831891298295), (4, 0.09764978475868702), (3, 0.09956173847119014), (4, 0.10127349756658077)]}), (4, {'avg': 0.10025716423988343, 'all': [(3, 0.09514620403448741), (5, 0.10259417444467545), (4, 0.1023276038467884), (4, 0.10598652064800262), (4, 0.09336932562291622)]}), (5, {'avg': 0.0947078741762949, 'all': [(3, 0.0970592200756073), (4, 0.0887072291225195), (6, 0.10431383053461711), (5, 0.09147146195173264), (5, 0.08980684727430344)]}), (6, {'avg': 0.09106763079762459, 'all': [(4, 0.08931001834571362), (4, 0.0894325990229845), (5, 0.0917548730969429), (3, 0.09620572874943416), (4, 0.08974764868617058)]}), (7, {'avg': 0.09605735875666141, 'all': [(4, 0.09806397184
# INFO flwr 2025-02-07 17:52:09,075 | app.py:253 | app_fit: losses_centralized [(0, 413.6842665672302), (1, 361.55588459968567), (2, 500.2706689834595), (3, 358.40403604507446), (4, 341.6076126098633), (5, 386.48018288612366), (6, 565.8231210708618), (7, 471.4497902393341), (8, 340.8493285179138), (9, 344.1057827472687), (10, 344.6642482280731), (11, 343.42808961868286), (12, 343.1178662776947), (13, 344.5231649875641), (14, 347.6397395133972), (15, 351.346706867218), (16, 352.8708539009094), (17, 352.3357708454132), (18, 351.6669955253601), (19, 351.9128863811493), (20, 353.43476462364197), (21, 357.30415177345276), (22, 360.97791814804077), (23, 364.490483045578), (24, 365.79721426963806), (25, 363.738721370697), (26, 361.5418028831482), (27, 359.5917224884033), (28, 358.89229917526245), (29, 359.51622557640076), (30, 360.3680307865143), (31, 361.6872646808624), (32, 362.907434463501), (33, 363.48985958099365), (34, 362.3165578842163), (35, 360.33272314071655), (36, 358.23461627960205), (37, 357.83945536613464), (38, 358.5328538417816), (39, 360.20058274269104), (40, 362.672554731369), (41, 363.31661224365234), (42, 361.6006336212158), (43, 359.6897647380829), (44, 357.5814633369446), (45, 356.98970198631287), (46, 356.96731328964233), (47, 357.42693042755127), (48, 357.634272813797), (49, 357.6656217575073), (50, 358.1183171272278)]
# INFO flwr 2025-02-07 17:52:09,075 | app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.0065625), (1, 0.074375), (2, 0.0965625), (3, 0.0884375), (4, 0.0721875), (5, 0.040625), (6, 0.1953125), (7, 0.12375), (8, 0.0765625), (9, 0.079375), (10, 0.0640625), (11, 0.0709375), (12, 0.0709375), (13, 0.070625), (14, 0.069375), (15, 0.079375), (16, 0.079375), (17, 0.079375), (18, 0.079375), (19, 0.079375), (20, 0.069375), (21, 0.069375), (22, 0.0709375), (23, 0.0709375), (24, 0.079375), (25, 0.079375), (26, 0.079375), (27, 0.079375), (28, 0.079375), (29, 0.079375), (30, 0.079375), (31, 0.070625), (32, 0.069375), (33, 0.069375), (34, 0.069375), (35, 0.069375), (36, 0.079375), (37, 0.079375), (38, 0.079375), (39, 0.079375), (40, 0.079375), (41, 0.079375), (42, 0.079375), (43, 0.079375), (44, 0.0709375), (45, 0.0709375), (46, 0.069375), (47, 0.069375), (48, 0.079375), (49, 0.079375), (50, 0.079375)]}

# %%
cos_similarities_momentum = cos_similarity_between_all_rounds(parameters_for_each_round_momentum)

x_values = np.arange(len(parameters_for_each_round_momentum) - 1)
fig, ax = plt.subplots(figsize=(6,6))
sns.set(style='whitegrid')
sns.lineplot(x=x_values, y=cos_similarities_momentum)
# Out:
# <Axes: >

# %% [markdown]
# We see that the added momentum gives a much smoother curve towards convergence, compared to the previous where we saw a lot of plateauing. Using momentum, there is less of an oscillation between the individual rounds, which helps to keep the gradient updates in more of the same direction. This is partciularly useful in our case with non-homogeneous data, as we avoid overfitting to different local data for whatever client is connected in the current round (where some client might e.g. only have data with one particular label, or particularly noisy data). This way, we get more of a smooth overall update in the direction of the final optimal model, even though the data in the single rounds might suggest the gradient to move all over the place.

# %% [markdown]
# (c) 2024 Alexandru-Andrei Iacob, Lorenzo Sani
