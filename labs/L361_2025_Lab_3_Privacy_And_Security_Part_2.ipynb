# %% [markdown]
# # 0. Marking.
#
# **_IMPORTANT_**: Save a copy of this notebook into your Drive before you start.
#
# - Please attempt all the questions marked for your group (Part II ✅ | Part III/MPhil ✅).
#
# Please submit a zip file, containing both parts, consiting of of:
#
# 1. A text file with a publicly visible link to your notebooks in Google Colab or GitHub.
# 2. A downloaded copy (ipynb) of your notebooks or your zipped cloned GitHub repo. You may treat these as a report: we will not be re-executing the code you used to produce the answers unless required.
#
# If you find yourself enjoying the material, feel free to attempt more! Provide your answers in a new cell below the question cell.

# %%
# !git clone https://github.com/AsbjornLorenzen/L361-Federated-Learning.git
# Out:
# fatal: destination path 'L361-Federated-Learning' already exists and is not an empty directory.

# %%
# !pip install flwr
# Out:
# Requirement already satisfied: flwr in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: cryptography<42.0.0,>=41.0.2 in /usr/local/lib/python3.11/dist-packages (from flwr) (41.0.2)
# Requirement already satisfied: grpcio!=1.52.0,<2.0.0,>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from flwr) (1.70.0)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /usr/local/lib/python3.11/dist-packages (from flwr) (0.0.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from flwr) (1.26.4)
# Requirement already satisfied: protobuf<4.0.0,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from flwr) (3.20.3)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from flwr) (3.18.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<42.0.0,>=41.0.2->flwr) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<42.0.0,>=41.0.2->flwr) (2.22)

# %% [markdown]
# ## Imports

# %%
# The simulation component of flower uses RAY under the hood.
# `pip` could produce some errors. Nothing to worry about.
# The execution has been verified; it is working anyway.
! pip install --quiet --upgrade "pip"
! pip install --quiet \
    git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching ray=="2.6.3" \
    torch=="2.2.1" torchvision=="0.17.1"  tqdm=="4.67.1" torchsummary=="1.5.1" \
    pycrypto cryptography=="41.0.2" pycryptodome=="3.18.0" matplotlib=="3.8.2"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 35.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 68.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 76.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 54.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 47.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 40.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 50.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 40.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 26.3 MB/s eta 0:00:00
#   Building wheel for flwr (pyproject.toml) ... done
#   Building wheel for pycrypto (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 41.0.2 which is incompatible.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.2.1 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<6.0.0dev,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.

# %%
# Imports
import os
import random
from collections.abc import Callable
from typing import Any
from pathlib import Path

import flwr as fl
import numpy as np

import torch
from flwr.client import Client
from flwr.common.typing import NDArrays
from flwr.server import ServerConfig, History
from flwr.server.strategy import Strategy
from enum import IntEnum
from datetime import datetime, timezone
import json


# Add new seeds here for easy autocomplete
class Seeds(IntEnum):
    """Seeds for reproducibility."""

    DEFAULT = 1337


np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

PathType = Path | str | None

# %% [markdown]
# ### Paths

# %%
home_dir = Path.cwd()
data_dir: Path = home_dir / "data"

# %% [markdown]
# ### Useful Python functions

# %%
def convert(o: Any) -> int | float:
    """Convert input object to Python numerical if numpy."""
    # type: ignore[reportGeneralTypeIssues]
    if isinstance(o, np.int32 | np.int64):
        return int(o)
    # type: ignore[reportGeneralTypeIssues]
    if isinstance(o, np.float32 | np.float64):
        return float(o)
    raise TypeError


def save_history(hist: History, name: str) -> None:
    """Save history from simulation to file."""
    time = int(datetime.now(timezone.utc).timestamp())
    path = home_dir / "histories"
    path.mkdir(exist_ok=True)
    path = path / f"hist_{time}_{name}.json"
    with open(path, "w", encoding="utf-8") as f:
        json.dump(hist.__dict__, f, ensure_ascii=False, indent=4, default=convert)


def start_seeded_simulation(
    client_fn: Callable[[str], Client],
    num_clients: int,
    config: ServerConfig,
    strategy: Strategy,
    name: str,
    seed: int = Seeds.DEFAULT,
    iteration: int = 0,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Wrap simulation to always seed client selection."""
    np.random.seed(seed ^ iteration)
    torch.manual_seed(seed ^ iteration)
    random.seed(seed ^ iteration)
    parameter_list, hist = fl.simulation.start_simulation_no_ray(
        client_fn=client_fn,
        num_clients=num_clients,
        client_resources={},
        config=config,
        strategy=strategy,
    )
    save_history(hist, name)
    return parameter_list, hist

# %% [markdown]
# ### Dataset

# %%
# %cd L361-Federated-Learning/labs
from common.client import get_flower_client_generator
from common.client_utils import (
    get_network_generator_cnn,
    get_model_parameters,
)
# Out:
# /content/L361-Federated-Learning/labs

# %%
np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
network_generator_cnn = get_network_generator_cnn()
seed_net_cnn = network_generator_cnn()
seed_model_cnn_params: NDArrays = get_model_parameters(seed_net_cnn)
federated_evaluation_function = None

# %%
fl_client_gen = get_flower_client_generator(network_generator_cnn, home_dir, home_dir)

# %% [markdown]
# # Secure Aggregation

# %% [markdown]
# In this section, we will explore a **Secure Multi-Party Computation (SMPC)** based approach first implemented in an FL context in [this](https://arxiv.org/abs/1611.04482) paper, called **Secure Aggregation**.
# The authors proposed a protocol for the secure aggregation of model updates in a Federated Learning setting.
# SMPC algorithms allow a group of _mutually distrustful parties_ to compute a function over their private inputs without revealing any information about their inputs to one another.
# In Federated Learning, users can compute the average of their model updates without revealing any information about their model updates to the other actors.
# This is achieved by a complex exchange of encrypted keys and messages between the actors, which is why the protocol is _computationally expensive_.
# The additional information the server and clients exchanges results in additional _communication overhead_.
# In this Lab, we will focus on the communication overhead, ignoring the computational overhead. Furthermore, the protocol requires a specific fraction of clients to complete training to compute the average.
#
# [Pan Heng](https://github.com/panh99) implemented the first Secure Aggregation in Flower. Thus, we will use part of his code in this section. However, because of the complexity of this protocol, we refer all the discussions to the original paper.
# The main takeaways from the paper are the following: private inputs of clients are completely protected in this setting; Secure Aggregation is computationally expensive and requires a lot of communication overhead; the scalability of Secure Aggregation to many clients requires a lot of computational resources.
#
# In the following cell, we will download the code for the Secure Aggregation protocol.

# %%
secagg_dir = home_dir / "secagg"

# %% [markdown]
# The implementation contains many encryption utilities, and thus it is very complex.
# So, feel free to dig into the code, but be aware that it is unnecessary to understand every part of it to complete the Lab.
#
# We also need to create a folder to store the keys generated on the fly by our simulation.

# %%
keys_dir = secagg_dir / "client_data"
keys_dir.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# We are now importing the relevant functions for simulating the Secure Aggregation protocol from the files we have just downloaded.

# %%
from common.secagg.client import get_sec_agg_client_generator as get_client_generator
from common.secagg.strategy import SecureAggregationStrategy

# %% [markdown]
# It is important to point out that from now on we will use a toy simulator.
# This means that we will not use real clients, so we are not training anything.
# We will just simulate the communication between the server and the clients to explore the communication overhead.
# The scripts are built to return to the `aggregate_fit` function of the server the length of the bytes exchanged during all the phases of communication of the Secure Aggregation protocol.
# The equivalent single FL training round is achieved in 4 phases of communication by the protocol.
#
# It is worth mentioning that for this implementation we will change our training round from using epochs to local steps because we need all the clients to train on the same amount of data samples.
# This is done because even the number of samples could be considered sensitive information that we do not want to reveal to the other actors.

# %%
num_total_clients = 3290

# %%
def run_sec_agg_demo(
    num_clients_per_round: int = 10,
    n_model_parameters: int = 10000,
    min_num_surviving_clients: int = 5,
    n_rounds: int = 2,
    n_samples: int = 30,
) -> Any:
    """Execute a secure aggregation simulation."""
    strategy = SecureAggregationStrategy(
        n_dim=n_model_parameters,
        num_clients_per_round=num_clients_per_round,
        threshold=min_num_surviving_clients,
        num_dropouts=num_clients_per_round - min_num_surviving_clients,
    )
    secagg_hist = start_seeded_simulation(
        client_fn=lambda cid: get_client_generator(
            n_model_parameters, n_samples, keys_dir
        )(cid).to_client(),
        num_clients=num_total_clients,
        # this refers to the number of phases to simulate (must be 4*n_rounds)
        config=ServerConfig(num_rounds=int(4 * n_rounds)),
        strategy=strategy,
        name=f"secagg_{num_clients_per_round}_{n_model_parameters}_{min_num_surviving_clients}_{n_rounds}_{n_samples}",
    )
    # Clean up keys from the folder
    for filename in os.listdir(keys_dir):
        file_pth = keys_dir / filename
        if filename.endswith(".pth"):
            Path.unlink(file_pth)

    return secagg_hist

# %% [markdown]
# In the next cell, we will simulate the Secure Aggregation protocol defined by the abovementioned parameters.

# %%
parameters_for_every_round, secagg_hist = run_sec_agg_demo()
# Out:
# INFO flwr 2025-02-25 02:27:25,365 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-25 02:27:25,377 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-25 02:27:25,381 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-25 02:27:25,382 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-25 02:27:25,385 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-25 02:27:25,387 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-25 02:27:25,390 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-25 02:27:25,393 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:27:25,397 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,399 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,404 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,406 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,406 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,411 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,440 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,446 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,448 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,453 | client.py:181 | Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,455 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,458 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,465 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,469 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,477 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,480 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,481 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-25 02:27:25,493 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,500 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:25,506 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:27:25,516 | server_returns_parameters.py:237 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:27:25,518 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:27:25,520 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-25 02:27:25,522 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:27:25,523 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:27:25,527 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-25 02:27:25,528 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:27:25,531 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:27:25,535 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:27:25,537 | client.py:221 | Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,537 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,545 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:27:25,553 | client.py:221 | Client 0: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,554 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:Client 0: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,571 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,572 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,572 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,695 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:25,735 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:27:25,762 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,784 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:25,791 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:25,810 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:25,819 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:27:25,841 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:27:25,855 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:27:25,860 | client.py:221 | Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,874 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,874 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:25,876 | client.py:221 | Client 3: starting stage 1...
# INFO flwr 2025-02-25 02:27:25,886 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: starting stage 1...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:25,985 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:26,035 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:26,037 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:26,039 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-25 02:27:26,056 | server_returns_parameters.py:237 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:27:26,059 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-25 02:27:26,062 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-25 02:27:26,065 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-25 02:27:26,068 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:27:26,074 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:27:26,076 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-25 02:27:26,077 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:27:26,077 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:27:26,079 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:27:26,081 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:27:26,085 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:27:26,089 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-25 02:27:26,097 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-25 02:27:26,099 | client.py:295 | Client 6: starting stage 2...
# INFO flwr 2025-02-25 02:27:26,108 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-25 02:27:26,112 | client.py:295 | Client 1: starting stage 2...
# INFO flwr 2025-02-25 02:27:26,125 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:27:26,145 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:Client 1: starting stage 2...
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-25 02:27:26,159 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:27:26,167 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:27:26,177 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:27:26,195 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:27:26,198 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:27:26,225 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:27:26,330 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:27:26,342 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:27:26,357 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:27:26,389 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:27:26,391 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-25 02:27:26,408 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 5 failures
# DEBUG:flwr:fit_round 3 received 5 results and 5 failures
# INFO flwr 2025-02-25 02:27:26,410 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:26,412 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:26,413 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:26,415 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:26,416 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:26,417 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-25 02:27:26,422 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# INFO flwr 2025-02-25 02:27:26,424 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-25 02:27:26,426 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 4: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-25 02:27:26,432 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:27:26,433 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:27:26,434 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:27:26,443 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:27:26,472 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# DEBUG flwr 2025-02-25 02:27:26,489 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
# DEBUG:flwr:fit_round 4 received 5 results and 0 failures
# INFO flwr 2025-02-25 02:27:26,493 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-25 02:27:27,346 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# INFO flwr 2025-02-25 02:27:27,353 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-25 02:27:27,354 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-25 02:27:27,359 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 5: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:27:27,361 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,364 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,365 | client.py:181 | Client 2: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,368 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,369 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,371 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,381 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,385 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,393 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,402 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,416 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,425 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,434 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,439 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,441 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,442 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-25 02:27:27,457 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,478 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,478 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:27:27,478 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:27:27,499 | server_returns_parameters.py:237 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:27:27,500 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:27:27,502 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-25 02:27:27,503 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:27:27,505 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 6: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:27:27,508 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:27:27,509 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:27:27,511 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:27:27,515 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:27:27,515 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:27:27,515 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:27:27,521 | client.py:221 | Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,522 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,527 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,531 | client.py:221 | Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,532 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,547 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,737 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:27,758 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:27,767 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:27:27,779 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:27:27,781 | client.py:221 | Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,803 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,857 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:27,880 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:27:27,882 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:27,900 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:27:27,901 | client.py:221 | Client 6: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,921 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-25 02:27:27,965 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:28,027 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:28,076 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:28,148 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:28,176 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:27:28,203 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-25 02:27:28,211 | server_returns_parameters.py:237 | fit_round 6 received 10 results and 0 failures
# DEBUG:flwr:fit_round 6 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:27:28,212 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-25 02:27:28,214 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-25 02:27:28,216 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-25 02:27:28,217 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 7: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:27:28,219 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:27:28,226 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,237 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:27:28,241 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:27:28,246 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:27:28,249 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:27:28,252 | client.py:295 | Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,252 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:27:28,255 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:27:28,271 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,278 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,272 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,284 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,287 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:27:28,295 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,299 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:27:28,319 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:27:28,329 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,334 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,343 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-25 02:27:28,437 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:27:28,475 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:27:28,530 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:27:28,530 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:27:28,540 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-25 02:27:28,555 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 5 failures
# DEBUG:flwr:fit_round 7 received 5 results and 5 failures
# INFO flwr 2025-02-25 02:27:28,559 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:28,560 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:28,562 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:28,563 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:28,565 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:27:28,566 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-25 02:27:28,572 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-25 02:27:28,573 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-25 02:27:28,577 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-25 02:27:28,581 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:27:28,589 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:27:28,599 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:27:28,603 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:27:28,603 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# DEBUG flwr 2025-02-25 02:27:28,631 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-25 02:27:28,636 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-25 02:27:29,411 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-25 02:27:29,417 | server_returns_parameters.py:150 | FL finished in 4.030021189999957
# INFO:flwr:FL finished in 4.030021189999957
# INFO flwr 2025-02-25 02:27:29,420 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-25 02:27:29,422 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}
# INFO flwr 2025-02-25 02:27:29,423 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-25 02:27:29,424 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-25 02:27:29,425 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}

# %%
secagg_hist
# Out:
# History (metrics, distributed, fit):
# {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}

# %% [markdown]
# **Question 9 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# Using the function `run_SA_demo`, study the impact of different parameters on the `total_cost`:
#
# 1. Draw a scatter plot with the `total_cost` summed across rounds on the y-axis. While keeping all other parameters constant to the above values, vary the `num_clients_per_round` from 10 to 40 using an increment of 10. Use the `num_clients_per_round` as the x-axis.
#
# 2. Draw a scatter plot with the `total_cost` summed across rounds on the y-axis. While keeping all other parameters constant to the above values, vary `n_model_parameters` between $2^{10}$ and $2^{15}$ increasing using all the powers of two in the interval. Use the `n_model_parameters` as the x-axis.
#
# 3. Describe the trade-offs you see and how they relate to communication overheads.

# %%
clients_per_round_cost = []
for i in range(4):
  num_clients = 10 + i * 10
  _, history = run_sec_agg_demo(num_clients_per_round=num_clients)
  clients_per_round_cost.append(history)

num_clients_list = [10 + i * 10 for i in range(4)]
# Out:
# INFO flwr 2025-02-25 02:31:42,168 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-25 02:31:42,216 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-25 02:31:42,219 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-25 02:31:42,223 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-25 02:31:42,226 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-25 02:31:42,229 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-25 02:31:42,230 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-25 02:31:42,236 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:42,239 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,242 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,246 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,246 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,251 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,266 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,255 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,282 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,255 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,261 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,284 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,286 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,288 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: starting stage 0...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,295 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,302 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,304 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,305 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-25 02:31:42,313 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,329 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:42,335 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:31:42,349 | server_returns_parameters.py:237 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:31:42,358 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:31:42,360 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:42,362 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:31:42,364 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:42,367 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-25 02:31:42,375 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-25 02:31:42,378 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,384 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:31:42,390 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,399 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:31:42,396 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,405 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:31:42,408 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:31:42,414 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,436 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,445 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,570 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,611 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:31:42,636 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,651 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,665 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:31:42,676 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,713 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,722 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,732 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-25 02:31:42,754 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,759 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,771 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:31:42,783 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-25 02:31:42,797 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,826 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,867 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,895 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:42,909 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-25 02:31:42,915 | server_returns_parameters.py:237 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:31:42,917 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-25 02:31:42,920 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:42,922 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-25 02:31:42,925 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:42,930 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-25 02:31:42,934 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:31:42,936 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:31:42,936 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,937 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:31:42,947 | client.py:295 | Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,948 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,949 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:31:42,950 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-25 02:31:42,959 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,964 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,968 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,968 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,969 | client.py:295 | Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,976 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:31:42,988 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:31:42,991 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:31:43,003 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:31:43,008 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-25 02:31:43,013 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:31:43,063 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:31:43,092 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:31:43,103 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:31:43,111 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:31:43,119 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-25 02:31:43,131 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 5 failures
# DEBUG:flwr:fit_round 3 received 5 results and 5 failures
# INFO flwr 2025-02-25 02:31:43,134 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:43,137 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:43,138 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:43,139 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:43,140 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:43,142 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-25 02:31:43,146 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:43,147 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-25 02:31:43,149 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 4: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:43,155 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:31:43,156 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:31:43,157 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:31:43,168 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:31:43,168 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# DEBUG flwr 2025-02-25 02:31:43,199 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
# DEBUG:flwr:fit_round 4 received 5 results and 0 failures
# INFO flwr 2025-02-25 02:31:43,202 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-25 02:31:43,667 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:43,670 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-25 02:31:43,671 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-25 02:31:43,676 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 5: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:43,680 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,682 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,685 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,692 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,700 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,703 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,704 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,717 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,722 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,725 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,731 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,734 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,736 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,750 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,737 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,753 | client.py:181 | Client 9: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,749 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-25 02:31:43,762 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,773 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:43,776 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:31:43,788 | server_returns_parameters.py:237 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:31:43,790 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:31:43,791 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:43,793 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:31:43,794 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 6: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:43,795 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:31:43,800 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:31:43,802 | client.py:221 | Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:31:43,805 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:31:43,811 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:31:43,808 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:31:43,813 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:31:43,818 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:31:43,820 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:Client 2: starting stage 1...
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:31:43,825 | client.py:221 | Client 4: starting stage 1...
# INFO flwr 2025-02-25 02:31:43,830 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-25 02:31:43,839 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-25 02:31:43,973 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:43,986 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:31:43,996 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:31:44,008 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:44,032 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:31:44,043 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-25 02:31:44,059 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:44,078 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:31:44,088 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:31:44,092 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:44,096 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:44,108 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:31:44,127 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-25 02:31:44,140 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:44,179 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:44,223 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:44,239 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:44,253 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-25 02:31:44,260 | server_returns_parameters.py:237 | fit_round 6 received 10 results and 0 failures
# DEBUG:flwr:fit_round 6 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:31:44,264 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-25 02:31:44,268 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:44,270 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-25 02:31:44,273 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 7: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:44,276 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:31:44,279 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:31:44,284 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,293 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,295 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:31:44,296 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:31:44,304 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:31:44,306 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:31:44,294 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:31:44,298 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:31:44,309 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:31:44,313 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,326 | client.py:295 | Client 5: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,328 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,329 | client.py:295 | Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,333 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,337 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:Client 4: starting stage 2...
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:31:44,368 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,368 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:31:44,387 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-25 02:31:44,450 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:31:44,477 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:31:44,490 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:31:44,506 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:31:44,512 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-25 02:31:44,526 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 5 failures
# DEBUG:flwr:fit_round 7 received 5 results and 5 failures
# INFO flwr 2025-02-25 02:31:44,528 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:44,530 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:44,530 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:44,531 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:44,532 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:31:44,533 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-25 02:31:44,541 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:44,542 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-25 02:31:44,544 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:44,545 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:31:44,546 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:31:44,548 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:31:44,559 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:31:44,563 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# DEBUG flwr 2025-02-25 02:31:44,597 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-25 02:31:44,598 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-25 02:31:45,078 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:45,080 | server_returns_parameters.py:150 | FL finished in 2.8510015389999808
# INFO:flwr:FL finished in 2.8510015389999808
# INFO flwr 2025-02-25 02:31:45,082 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-25 02:31:45,083 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}
# INFO flwr 2025-02-25 02:31:45,085 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-25 02:31:45,086 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-25 02:31:45,087 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# INFO flwr 2025-02-25 02:31:46,044 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-25 02:31:46,062 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-25 02:31:46,066 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-25 02:31:46,074 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-25 02:31:46,076 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-25 02:31:46,077 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-25 02:31:46,079 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-25 02:31:46,081 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 20 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 20 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:46,085 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,092 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,100 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,101 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,110 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,112 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,123 | client.py:181 | Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,124 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,126 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,126 | client.py:181 | Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,126 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,133 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,138 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,148 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,149 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,154 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,158 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,164 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,166 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,175 | client.py:181 | Client 10: starting stage 0...
# INFO:flwr:Client 10: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,175 | client.py:181 | Client 11: starting stage 0...
# INFO:flwr:Client 11: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,176 | client.py:181 | Client 12: starting stage 0...
# INFO:flwr:Client 12: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,187 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,196 | client.py:181 | Client 13: starting stage 0...
# INFO:flwr:Client 13: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,197 | client.py:181 | Client 14: starting stage 0...
# INFO:flwr:Client 14: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,207 | client.py:209 | Client 10: stage 0 completes. uploading public keys...
# INFO:flwr:Client 10: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,225 | client.py:209 | Client 11: stage 0 completes. uploading public keys...
# INFO:flwr:Client 11: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,228 | client.py:209 | Client 12: stage 0 completes. uploading public keys...
# INFO:flwr:Client 12: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,229 | client.py:181 | Client 15: starting stage 0...
# INFO:flwr:Client 15: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,230 | client.py:209 | Client 13: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,234 | client.py:209 | Client 14: stage 0 completes. uploading public keys...
# INFO:flwr:Client 13: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,237 | client.py:181 | Client 16: starting stage 0...
# INFO:flwr:Client 14: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,242 | client.py:181 | Client 17: starting stage 0...
# INFO:flwr:Client 16: starting stage 0...
# INFO:flwr:Client 17: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,249 | client.py:181 | Client 18: starting stage 0...
# INFO:flwr:Client 18: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,259 | client.py:209 | Client 15: stage 0 completes. uploading public keys...
# INFO:flwr:Client 15: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,260 | client.py:181 | Client 19: starting stage 0...
# INFO flwr 2025-02-25 02:31:46,271 | client.py:209 | Client 16: stage 0 completes. uploading public keys...
# INFO:flwr:Client 19: starting stage 0...
# INFO:flwr:Client 16: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,300 | client.py:209 | Client 18: stage 0 completes. uploading public keys...
# INFO:flwr:Client 18: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,309 | client.py:209 | Client 19: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:31:46,310 | client.py:209 | Client 17: stage 0 completes. uploading public keys...
# INFO:flwr:Client 19: stage 0 completes. uploading public keys...
# INFO:flwr:Client 17: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:31:46,328 | server_returns_parameters.py:237 | fit_round 1 received 20 results and 0 failures
# DEBUG:flwr:fit_round 1 received 20 results and 0 failures
# INFO flwr 2025-02-25 02:31:46,331 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:31:46,333 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-25 02:31:46,337 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:31:46,340 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 20 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 20 clients (out of 3290)
# INFO flwr 2025-02-25 02:31:46,344 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:31:46,345 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:31:46,355 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:31:46,363 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-25 02:31:46,364 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:31:46,367 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:31:46,370 | client.py:221 | Client 6: starting stage 1...
# INFO flwr 2025-02-25 02:31:46,370 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:31:46,378 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:31:46,390 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-25 02:31:46,410 | client.py:221 | Client 12: starting stage 1...
# INFO:flwr:Client 12: starting stage 1...
# INFO flwr 2025-02-25 02:31:46,415 | client.py:221 | Client 16: starting stage 1...
# INFO:flwr:Client 16: starting stage 1...
# INFO flwr 2025-02-25 02:31:46,784 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:46,812 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:31:46,821 | client.py:221 | Client 14: starting stage 1...
# INFO:flwr:Client 14: starting stage 1...
# INFO flwr 2025-02-25 02:31:46,830 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:46,849 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:31:46,863 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:31:46,910 | client.py:287 | Client 16: stage 1 completes. uploading key shares...
# INFO:flwr:Client 16: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:46,977 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:31:46,998 | client.py:221 | Client 11: starting stage 1...
# INFO:flwr:Client 11: starting stage 1...
# INFO flwr 2025-02-25 02:31:47,017 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:47,019 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:47,044 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:31:47,054 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:31:47,056 | client.py:287 | Client 12: stage 1 completes. uploading key shares...
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:Client 12: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:47,061 | client.py:221 | Client 19: starting stage 1...
# INFO:flwr:Client 19: starting stage 1...
# INFO flwr 2025-02-25 02:31:47,076 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:31:47,073 | client.py:221 | Client 17: starting stage 1...
# INFO:flwr:Client 17: starting stage 1...
# INFO flwr 2025-02-25 02:31:47,093 | client.py:221 | Client 10: starting stage 1...
# INFO:flwr:Client 10: starting stage 1...
# INFO flwr 2025-02-25 02:31:47,237 | client.py:287 | Client 14: stage 1 completes. uploading key shares...
# INFO:flwr:Client 14: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:47,277 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:31:47,304 | client.py:221 | Client 13: starting stage 1...
# INFO:flwr:Client 13: starting stage 1...
# INFO flwr 2025-02-25 02:31:47,375 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:31:47,393 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-25 02:31:47,455 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# ...
# INFO:flwr:CID 51 reloading from /content/secagg/client_data/51.pth
# INFO flwr 2025-02-25 02:32:43,060 | client.py:295 | Client 11: starting stage 2...
# INFO:flwr:Client 11: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,069 | client.py:146 | CID 807 reloading from /content/secagg/client_data/807.pth
# INFO:flwr:CID 807 reloading from /content/secagg/client_data/807.pth
# INFO flwr 2025-02-25 02:32:43,051 | client.py:146 | CID 179 reloading from /content/secagg/client_data/179.pth
# INFO:flwr:CID 179 reloading from /content/secagg/client_data/179.pth
# INFO flwr 2025-02-25 02:32:43,098 | client.py:295 | Client 30: starting stage 2...
# INFO:flwr:Client 30: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,083 | client.py:295 | Client 39: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,094 | client.py:146 | CID 1287 reloading from /content/secagg/client_data/1287.pth
# INFO:flwr:Client 39: starting stage 2...
# INFO:flwr:CID 1287 reloading from /content/secagg/client_data/1287.pth
# INFO flwr 2025-02-25 02:32:43,094 | client.py:146 | CID 701 reloading from /content/secagg/client_data/701.pth
# INFO:flwr:CID 701 reloading from /content/secagg/client_data/701.pth
# INFO flwr 2025-02-25 02:32:43,080 | client.py:146 | CID 2767 reloading from /content/secagg/client_data/2767.pth
# INFO:flwr:CID 2767 reloading from /content/secagg/client_data/2767.pth
# INFO flwr 2025-02-25 02:32:43,103 | client.py:295 | Client 20: starting stage 2...
# INFO:flwr:Client 20: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,110 | client.py:146 | CID 3259 reloading from /content/secagg/client_data/3259.pth
# INFO:flwr:CID 3259 reloading from /content/secagg/client_data/3259.pth
# INFO flwr 2025-02-25 02:32:43,131 | client.py:295 | Client 38: starting stage 2...
# INFO:flwr:Client 38: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,142 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,141 | client.py:295 | Client 26: starting stage 2...
# INFO:flwr:Client 26: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,158 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,170 | client.py:146 | CID 1887 reloading from /content/secagg/client_data/1887.pth
# INFO:flwr:CID 1887 reloading from /content/secagg/client_data/1887.pth
# INFO flwr 2025-02-25 02:32:43,194 | client.py:146 | CID 2364 reloading from /content/secagg/client_data/2364.pth
# INFO:flwr:CID 2364 reloading from /content/secagg/client_data/2364.pth
# INFO flwr 2025-02-25 02:32:43,195 | client.py:146 | CID 3068 reloading from /content/secagg/client_data/3068.pth
# INFO:flwr:CID 3068 reloading from /content/secagg/client_data/3068.pth
# INFO flwr 2025-02-25 02:32:43,204 | client.py:146 | CID 275 reloading from /content/secagg/client_data/275.pth
# INFO flwr 2025-02-25 02:32:43,210 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:CID 275 reloading from /content/secagg/client_data/275.pth
# INFO flwr 2025-02-25 02:32:43,215 | client.py:295 | Client 18: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO:flwr:Client 18: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,227 | client.py:295 | Client 35: starting stage 2...
# INFO:flwr:Client 35: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,228 | client.py:295 | Client 14: starting stage 2...
# INFO:flwr:Client 14: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,239 | client.py:146 | CID 823 reloading from /content/secagg/client_data/823.pth
# INFO:flwr:CID 823 reloading from /content/secagg/client_data/823.pth
# INFO flwr 2025-02-25 02:32:43,249 | client.py:146 | CID 2476 reloading from /content/secagg/client_data/2476.pth
# INFO:flwr:CID 2476 reloading from /content/secagg/client_data/2476.pth
# INFO flwr 2025-02-25 02:32:43,270 | client.py:146 | CID 485 reloading from /content/secagg/client_data/485.pth
# INFO:flwr:CID 485 reloading from /content/secagg/client_data/485.pth
# INFO flwr 2025-02-25 02:32:43,277 | client.py:295 | Client 12: starting stage 2...
# INFO:flwr:Client 12: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,282 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,310 | client.py:146 | CID 1668 reloading from /content/secagg/client_data/1668.pth
# INFO:flwr:CID 1668 reloading from /content/secagg/client_data/1668.pth
# INFO flwr 2025-02-25 02:32:43,318 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,328 | client.py:146 | CID 1285 reloading from /content/secagg/client_data/1285.pth
# INFO flwr 2025-02-25 02:32:43,349 | client.py:295 | Client 22: starting stage 2...
# INFO:flwr:CID 1285 reloading from /content/secagg/client_data/1285.pth
# INFO flwr 2025-02-25 02:32:43,366 | client.py:146 | CID 2152 reloading from /content/secagg/client_data/2152.pth
# INFO:flwr:Client 22: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,372 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:CID 2152 reloading from /content/secagg/client_data/2152.pth
# INFO flwr 2025-02-25 02:32:43,387 | client.py:146 | CID 1852 reloading from /content/secagg/client_data/1852.pth
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,393 | client.py:295 | Client 16: starting stage 2...
# INFO:flwr:CID 1852 reloading from /content/secagg/client_data/1852.pth
# INFO flwr 2025-02-25 02:32:43,419 | client.py:146 | CID 806 reloading from /content/secagg/client_data/806.pth
# INFO:flwr:Client 16: starting stage 2...
# INFO:flwr:CID 806 reloading from /content/secagg/client_data/806.pth
# INFO flwr 2025-02-25 02:32:43,434 | client.py:295 | Client 34: starting stage 2...
# INFO:flwr:Client 34: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,447 | client.py:146 | CID 2243 reloading from /content/secagg/client_data/2243.pth
# INFO:flwr:CID 2243 reloading from /content/secagg/client_data/2243.pth
# INFO flwr 2025-02-25 02:32:43,461 | client.py:295 | Client 29: starting stage 2...
# INFO:flwr:Client 29: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,496 | client.py:295 | Client 13: starting stage 2...
# INFO:flwr:Client 13: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,523 | client.py:146 | CID 1872 reloading from /content/secagg/client_data/1872.pth
# INFO:flwr:CID 1872 reloading from /content/secagg/client_data/1872.pth
# INFO flwr 2025-02-25 02:32:43,528 | client.py:146 | CID 2329 reloading from /content/secagg/client_data/2329.pth
# INFO:flwr:CID 2329 reloading from /content/secagg/client_data/2329.pth
# INFO flwr 2025-02-25 02:32:43,560 | client.py:146 | CID 3269 reloading from /content/secagg/client_data/3269.pth
# INFO:flwr:CID 3269 reloading from /content/secagg/client_data/3269.pth
# INFO flwr 2025-02-25 02:32:43,566 | client.py:295 | Client 9: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,567 | client.py:295 | Client 37: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO:flwr:Client 37: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,611 | client.py:295 | Client 36: starting stage 2...
# INFO:flwr:Client 36: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,637 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:32:43,661 | client.py:295 | Client 28: starting stage 2...
# INFO:flwr:Client 28: starting stage 2...
# INFO flwr 2025-02-25 02:32:43,721 | client.py:146 | CID 295 reloading from /content/secagg/client_data/295.pth
# INFO:flwr:CID 295 reloading from /content/secagg/client_data/295.pth
# INFO flwr 2025-02-25 02:32:43,766 | client.py:295 | Client 21: starting stage 2...
# INFO:flwr:Client 21: starting stage 2...
# INFO flwr 2025-02-25 02:32:44,140 | client.py:397 | Client 39: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 39: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:32:44,178 | client.py:397 | Client 38: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 38: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:32:44,225 | client.py:397 | Client 35: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 35: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:32:44,279 | client.py:397 | Client 37: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 37: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:32:44,295 | client.py:397 | Client 36: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 36: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-25 02:32:44,304 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 35 failures
# DEBUG:flwr:fit_round 7 received 5 results and 35 failures
# INFO flwr 2025-02-25 02:32:44,307 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,308 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,309 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,310 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,311 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,312 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,313 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,314 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,315 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,315 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,321 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,322 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,324 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,328 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,329 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,330 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,331 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,332 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,333 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,334 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,335 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,336 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,338 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,342 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,343 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,345 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,346 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,347 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,349 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,349 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,350 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,352 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,353 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,354 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,356 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:32:44,357 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-25 02:32:44,362 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-25 02:32:44,364 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-25 02:32:44,366 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-25 02:32:44,374 | client.py:146 | CID 1287 reloading from /content/secagg/client_data/1287.pth
# INFO:flwr:CID 1287 reloading from /content/secagg/client_data/1287.pth
# INFO flwr 2025-02-25 02:32:44,388 | client.py:146 | CID 51 reloading from /content/secagg/client_data/51.pth
# INFO:flwr:CID 51 reloading from /content/secagg/client_data/51.pth
# INFO flwr 2025-02-25 02:32:44,389 | client.py:146 | CID 2329 reloading from /content/secagg/client_data/2329.pth
# INFO:flwr:CID 2329 reloading from /content/secagg/client_data/2329.pth
# INFO flwr 2025-02-25 02:32:44,412 | client.py:146 | CID 3269 reloading from /content/secagg/client_data/3269.pth
# INFO:flwr:CID 3269 reloading from /content/secagg/client_data/3269.pth
# INFO flwr 2025-02-25 02:32:44,422 | client.py:146 | CID 3068 reloading from /content/secagg/client_data/3068.pth
# INFO:flwr:CID 3068 reloading from /content/secagg/client_data/3068.pth
# DEBUG flwr 2025-02-25 02:32:44,449 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-25 02:32:44,451 | strategy.py:186 | Length of content is 17406
# INFO:flwr:Length of content is 17406
# INFO flwr 2025-02-25 02:32:50,253 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-25 02:32:50,256 | server_returns_parameters.py:150 | FL finished in 33.55656842600001
# INFO:flwr:FL finished in 33.55656842600001
# INFO flwr 2025-02-25 02:32:50,257 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-25 02:32:50,263 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 18000), (2, 1360640), (3, 401340), (4, 87030), (5, 18000), (6, 1360640), (7, 401340), (8, 87030)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 18000), (2, 1360640), (3, 401340), (4, 87030), (5, 18000), (6, 1360640), (7, 401340), (8, 87030)]}
# INFO flwr 2025-02-25 02:32:50,265 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-25 02:32:50,267 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-25 02:32:50,270 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}

# %%
import itertools

total_costs = []
for c in clients_per_round_cost:
    cost = [cost for _, cost in c.metrics_distributed_fit['total_cost']]
    total_costs.append(cost)
# Out:
# [4500, 83660, 485000, 499430, 503930, 583090, 984430, 998860]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter([10], [sum(total_costs[0])], label='Total cost with 10 clients')
plt.scatter([20], [sum(total_costs[1])], label='Total cost with 20 clients')
plt.scatter([30], [sum(total_costs[2])], label='Total cost with 30 clients')
plt.scatter([40], [sum(total_costs[3])], label='Total cost with 40 clients')

plt.legend()
plt.show()

# %%
n_params_cost = []
for i in range(10,16):
  n_params = 2 ** i
  _, cost = run_sec_agg_demo(n_model_parameters=n_params)
  n_params_cost.append(cost)
# Out:
# INFO flwr 2025-02-25 02:51:24,700 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-25 02:51:24,733 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-25 02:51:24,735 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-25 02:51:24,738 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-25 02:51:24,740 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-25 02:51:24,742 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-25 02:51:24,743 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-25 02:51:24,749 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:24,752 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,757 | client.py:181 | Client 2: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,761 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,766 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,769 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,769 | client.py:181 | Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,769 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,772 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,778 | client.py:181 | Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,779 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,785 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: starting stage 0...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,791 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,794 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,807 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,809 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,807 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-25 02:51:24,813 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,817 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,823 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: starting stage 0...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:24,836 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:51:24,842 | server_returns_parameters.py:237 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:51:24,843 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:51:24,845 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:24,846 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:51:24,848 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:24,852 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:51:24,853 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:51:24,856 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:51:24,858 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-25 02:51:24,860 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-25 02:51:24,863 | client.py:221 | Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:51:24,864 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:51:24,872 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:51:24,873 | client.py:221 | Client 2: starting stage 1...
# INFO flwr 2025-02-25 02:51:24,876 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:51:24,884 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-25 02:51:24,894 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-25 02:51:25,012 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,027 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:51:25,049 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-25 02:51:25,076 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,094 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,101 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:51:25,113 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:51:25,116 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:51:25,123 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,131 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-25 02:51:25,135 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-25 02:51:25,144 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,146 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-25 02:51:25,154 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,243 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,265 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,273 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:25,281 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-25 02:51:25,287 | server_returns_parameters.py:237 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:51:25,289 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-25 02:51:25,290 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:25,292 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-25 02:51:25,293 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:25,296 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:51:25,300 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,306 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:51:25,306 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:51:25,317 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,318 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:51:25,319 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-25 02:51:25,320 | client.py:295 | Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,321 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:51:25,332 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,337 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:51:25,340 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-25 02:51:25,349 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,355 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:Client 5: starting stage 2...
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:51:25,358 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-25 02:51:25,363 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,389 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,381 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,400 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:51:25,422 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:51:25,473 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:25,479 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:25,499 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:25,513 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:25,526 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-25 02:51:25,533 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 5 failures
# DEBUG:flwr:fit_round 3 received 5 results and 5 failures
# INFO flwr 2025-02-25 02:51:25,536 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:25,539 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:25,540 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:25,541 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:25,543 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:25,545 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-25 02:51:25,549 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:25,551 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-25 02:51:25,553 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 4: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:25,562 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:51:25,564 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:51:25,565 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:51:25,565 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:51:25,579 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# DEBUG flwr 2025-02-25 02:51:25,601 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
# DEBUG:flwr:fit_round 4 received 5 results and 0 failures
# INFO flwr 2025-02-25 02:51:25,604 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-25 02:51:26,066 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:26,068 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-25 02:51:26,069 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-25 02:51:26,072 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 5: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:26,075 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,082 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,083 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,092 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,096 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,097 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,098 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,107 | client.py:181 | Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,108 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,108 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,112 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,115 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,120 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: starting stage 0...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,134 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,132 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,132 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,133 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-25 02:51:26,123 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,156 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:26,162 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:51:26,171 | server_returns_parameters.py:237 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:51:26,172 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:51:26,174 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:26,175 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:51:26,177 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 6: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:26,180 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:51:26,182 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:51:26,183 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:51:26,186 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:51:26,190 | client.py:221 | Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,191 | client.py:221 | Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,191 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,192 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,195 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,207 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:51:26,211 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,221 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,408 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,416 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,430 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,438 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,444 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:51:26,447 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:51:26,448 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:51:26,460 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,466 | client.py:221 | Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,466 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: starting stage 1...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,467 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,470 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,474 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:51:26,499 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-25 02:51:26,612 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,619 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,637 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:26,646 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-25 02:51:26,653 | server_returns_parameters.py:237 | fit_round 6 received 10 results and 0 failures
# DEBUG:flwr:fit_round 6 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:51:26,656 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-25 02:51:26,659 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:26,661 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-25 02:51:26,666 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 7: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:26,669 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:51:26,670 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:51:26,674 | client.py:295 | Client 4: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,675 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:Client 4: starting stage 2...
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:51:26,682 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,679 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:51:26,687 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,690 | client.py:295 | Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,690 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:51:26,692 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:Client 3: starting stage 2...
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:51:26,705 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:51:26,707 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:51:26,709 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:Client 2: starting stage 2...
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:51:26,719 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:51:26,722 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,723 | client.py:295 | Client 6: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,727 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,745 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,752 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:51:26,765 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-25 02:51:26,797 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:26,818 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:26,844 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:26,850 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:26,856 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-25 02:51:26,864 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 5 failures
# DEBUG:flwr:fit_round 7 received 5 results and 5 failures
# INFO flwr 2025-02-25 02:51:26,867 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:26,869 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:26,872 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:26,873 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:26,876 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:26,877 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-25 02:51:26,881 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:26,882 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-25 02:51:26,885 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:26,887 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:51:26,897 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:51:26,899 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:51:26,902 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:51:26,907 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# DEBUG flwr 2025-02-25 02:51:26,928 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-25 02:51:26,930 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-25 02:51:27,340 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:27,343 | server_returns_parameters.py:150 | FL finished in 2.601777573000163
# INFO:flwr:FL finished in 2.601777573000163
# INFO flwr 2025-02-25 02:51:27,347 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-25 02:51:27,349 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 42300), (4, 14430), (5, 4500), (6, 79160), (7, 42300), (8, 14430)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 42300), (4, 14430), (5, 4500), (6, 79160), (7, 42300), (8, 14430)]}
# INFO flwr 2025-02-25 02:51:27,350 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-25 02:51:27,352 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-25 02:51:27,353 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# INFO flwr 2025-02-25 02:51:27,459 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-25 02:51:27,483 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-25 02:51:27,485 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-25 02:51:27,487 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-25 02:51:27,488 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-25 02:51:27,490 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-25 02:51:27,492 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-25 02:51:27,494 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:27,497 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,505 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,506 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,515 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,516 | client.py:181 | Client 4: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,516 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: starting stage 0...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,531 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,544 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,552 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,563 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,559 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,557 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,584 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,570 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,570 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,577 | client.py:181 | Client 8: starting stage 0...
# INFO flwr 2025-02-25 02:51:27,566 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: starting stage 0...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,598 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,604 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:27,613 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:51:27,624 | server_returns_parameters.py:237 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:51:27,625 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:51:27,626 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:27,627 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:51:27,629 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:27,633 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-25 02:51:27,635 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:51:27,637 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:51:27,642 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:51:27,642 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:51:27,640 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-25 02:51:27,649 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-25 02:51:27,651 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-25 02:51:27,653 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-25 02:51:27,655 | client.py:221 | Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:51:27,660 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:51:27,665 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:51:27,761 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:27,774 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-25 02:51:27,783 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-25 02:51:27,865 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:27,897 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-25 02:51:27,913 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-25 02:51:27,966 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:27,983 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:27,987 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:51:28,001 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:28,003 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:51:28,018 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:28,025 | client.py:221 | Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:51:28,026 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:51:28,030 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: starting stage 1...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:28,080 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:28,137 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:28,138 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-25 02:51:28,149 | server_returns_parameters.py:237 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:51:28,150 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-25 02:51:28,152 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:28,153 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-25 02:51:28,156 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:28,160 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-25 02:51:28,162 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-25 02:51:28,162 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-25 02:51:28,171 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,172 | client.py:295 | Client 4: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,178 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:Client 4: starting stage 2...
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-25 02:51:28,187 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:51:28,180 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-25 02:51:28,173 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,195 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-25 02:51:28,174 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-25 02:51:28,196 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,198 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-25 02:51:28,202 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,205 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,214 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,228 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,233 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-25 02:51:28,248 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-25 02:51:28,249 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# ...
# INFO:flwr:Client 2: starting stage 0...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,424 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,462 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,458 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-25 02:51:44,435 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-25 02:51:44,465 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,467 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,486 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,491 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-25 02:51:44,495 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,509 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,514 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-25 02:51:44,523 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-25 02:51:44,550 | server_returns_parameters.py:237 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:51:44,551 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-25 02:51:44,553 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:44,555 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-25 02:51:44,559 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 6: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:44,562 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:51:44,563 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:51:44,563 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:51:44,567 | client.py:221 | Client 4: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,567 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:Client 4: starting stage 1...
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:51:44,567 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:51:44,574 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:51:44,577 | client.py:221 | Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,585 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,600 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,600 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,607 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,761 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:44,779 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:44,798 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:51:44,802 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:51:44,810 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,822 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,861 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:44,881 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:51:44,891 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,921 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:44,932 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:51:44,940 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-25 02:51:44,975 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:45,042 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:45,086 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:45,116 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:45,191 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-25 02:51:45,226 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-25 02:51:45,235 | server_returns_parameters.py:237 | fit_round 6 received 10 results and 0 failures
# DEBUG:flwr:fit_round 6 received 10 results and 0 failures
# INFO flwr 2025-02-25 02:51:45,236 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-25 02:51:45,239 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:45,240 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-25 02:51:45,243 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 7: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:45,244 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-25 02:51:45,245 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:51:45,246 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:51:45,248 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:51:45,248 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:51:45,249 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-25 02:51:45,270 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:51:45,278 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-25 02:51:45,281 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-25 02:51:45,272 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-25 02:51:45,283 | client.py:295 | Client 4: starting stage 2...
# INFO flwr 2025-02-25 02:51:45,290 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-25 02:51:45,318 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:Client 4: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-25 02:51:45,323 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-25 02:51:45,330 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-25 02:51:45,353 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-25 02:51:45,365 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:51:45,368 | client.py:295 | Client 3: starting stage 2...
# INFO flwr 2025-02-25 02:51:45,368 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-25 02:51:45,377 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-25 02:51:45,467 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:45,501 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:45,527 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:45,570 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-25 02:51:45,574 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-25 02:51:45,592 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 5 failures
# DEBUG:flwr:fit_round 7 received 5 results and 5 failures
# INFO flwr 2025-02-25 02:51:45,594 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:45,597 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:45,598 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:45,599 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:45,600 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-25 02:51:45,602 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-25 02:51:45,606 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:45,608 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-25 02:51:45,611 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-25 02:51:45,619 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-25 02:51:45,626 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-25 02:51:45,627 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-25 02:51:45,642 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-25 02:51:45,645 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# DEBUG flwr 2025-02-25 02:51:45,673 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-25 02:51:45,674 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-25 02:51:46,644 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-25 02:51:46,647 | server_returns_parameters.py:150 | FL finished in 4.488163778999933
# INFO:flwr:FL finished in 4.488163778999933
# INFO flwr 2025-02-25 02:51:46,648 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-25 02:51:46,651 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 1312060), (4, 14430), (5, 4500), (6, 79160), (7, 1312060), (8, 14430)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 1312060), (4, 14430), (5, 4500), (6, 79160), (7, 1312060), (8, 14430)]}
# INFO flwr 2025-02-25 02:51:46,652 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-25 02:51:46,653 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-25 02:51:46,655 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}

# %%
total_costs_params = []
for c in n_params_cost:
    cost = [cost for _, cost in c.metrics_distributed_fit['total_cost']]
    total_costs_params.append(sum(cost))

n_params = [2 ** i for i in range(10,16)]

# %%
print(total_costs_params)
# Out:
# [280780, 362700, 526540, 854220, 1509580, 2820300]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(n_params, [total_costs_params], label='Total cost with varying numbers of params')

plt.legend()
plt.show()

# %% [markdown]
# 3. We see that the communication overhead scales linearly with the parameter size and exponentially with the number of clients. We would expect this, since the parameters show the amount of data each client must transfer, and since an increasing number of clients requires each client to communicate more.

# %% [markdown]
# Looking carefully at the `History` object returned by the simulation, we can see that it contains the key `total_cost`, which couples the round of communication with the number of bytes exchanged during that round.
# Note that the values are periodic because of the 4 phases involved in the protocol.

# %% [markdown]
# **Question 10 (Part III/MPhil ✅):**
#
# (This is a purely conceptual question. Answer in **no more than 10 sentences each**.)
#
# After reading the [paper](https://arxiv.org/abs/1611.04482) and experimenting with the additional communication costs of Secure Aggregation in FL, discuss the implication of using this protocol in a real FL setting. You may want to discriminate between cross-silo and cross-device settings. You can focus on communication and computation overheads and refer to the asymptotic complexity of both.

# %% [markdown]
# The protocol ensures privacy by securely aggregating model updates. In a cross-silo setting (fewer, powerful devices), the protocol is more feasible because the number of participants is small, and they have sufficient computational resources. Communication and computation overheads are manageable here.
#
# In cross-device settings (many devices like smartphones), the protocol faces significant challenges. The communication overhead grows due to the large number of devices, and the cryptographic operations required for security can be computationally expensive, especially for resource-constrained devices. This leads to slower convergence and potential deployment issues.
#
# Asymptotically, the protocol’s complexity increases with the number of devices, making it less efficient for large-scale cross-device FL. In such cases, optimizing for communication and computation overheads becomes crucial, potentially by using hybrid or approximate methods.

# %% [markdown]
# (c) 2024 Alexandru-Andrei Iacob, Lorenzo Sani
